# %% [markdown]
# ### Prepare

# %%
#coutils package
# !pip install git+https://github.com/Mooozer/starterCode_-fromJohnson
import coutils
from coutils import fix_random_seed
# Out:
# Collecting git+https://github.com/Mooozer/starterCode_-fromJohnson
#   Cloning https://github.com/Mooozer/starterCode_-fromJohnson to /tmp/pip-req-build-jtn04pfr
#   Running command git clone -q https://github.com/Mooozer/starterCode_-fromJohnson /tmp/pip-req-build-jtn04pfr
# Requirement already satisfied (use --upgrade to upgrade): Colab-Utils==0.1.dev0 from git+https://github.com/Mooozer/starterCode_-fromJohnson in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: pydrive in /usr/local/lib/python3.6/dist-packages (from Colab-Utils==0.1.dev0) (1.3.1)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from pydrive->Colab-Utils==0.1.dev0) (3.13)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pydrive->Colab-Utils==0.1.dev0) (4.1.3)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from pydrive->Colab-Utils==0.1.dev0) (1.7.12)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (0.17.4)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (0.4.8)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (4.6)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (3.0.1)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (1.17.2)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (51.1.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (4.2.0)
# Building wheels for collected packages: Colab-Utils
#   Building wheel for Colab-Utils (setup.py) ... done
#   Created wheel for Colab-Utils: filename=Colab_Utils-0.1.dev0-cp36-none-any.whl size=10324 sha256=290bd9a54fc0a58f2790fd4772e9365df2ef1ba8ceeea0cfbce5d777c9b4a3a4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c391dy6e/wheels/33/99/25/c7b075b8e2708cf81105eb4209afcb8720adb16a42675822dc
# Successfully built Colab-Utils

# %%
import numpy as np
import pandas as pd
from collections import OrderedDict
import math
import time

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
import matplotlib.pyplot as plt

if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %%
# data type and device for torch.tensor
to_float = {'dtype': torch.float, 'device': 'cpu'}
to_float_cuda = {'dtype': torch.float, 'device': 'cuda'}
to_double = {'dtype': torch.double, 'device': 'cpu'}
to_double_cuda = {'dtype': torch.double, 'device': 'cuda'}
to_long = {'dtype': torch.long, 'device': 'cpu'}
to_long_cuda = {'dtype': torch.long, 'device': 'cuda'}

# %% [markdown]
# ### Load Data

# %%
from google.colab import files
uploaded = files.upload()  #merged_sur_hrv_hr.csv  and  rrdata.csv
# Out:
#      <input type="file" id="files-1afb4aa3-5fe0-4b56-bf5d-7c5ad4be489c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1afb4aa3-5fe0-4b56-bf5d-7c5ad4be489c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving merged_sur_hrv_hr.csv to merged_sur_hrv_hr.csv

# %%
rrdata = pd.read_csv('rrdata.csv')
data = pd.read_csv('merged_sur_hrv_hr.csv')
data['time_of_day'] = data['time_of_day'].map( {'morning':0 , 'day':1, 'evening':2, 'night':3} )

# %%
data0 = data[['time_of_day','heart_rate', 'bpm', 'meanrr', 'mxdmn', 'sdnn',
       'rmssd', 'pnn50', 'mode', 'amo', 'lf', 'hf', 'vlf', 'lfhf',
       'total_power', 'day_after_test', 'S_COVID_BREATH', 'S_COVID_CONFUSION',
       'S_COVID_COUGH', 'S_COVID_FATIGUE', 'S_COVID_FEVER', 'S_COVID_PAIN',
       'S_COVID_BLUISH', 'class4']]
data1 = data[['time_of_day','bpm', 'meanrr', 'mxdmn', 'sdnn',
       'rmssd', 'pnn50', 'mode', 'amo', 'lf', 'hf', 'vlf', 'lfhf',
       'total_power', 'day_after_test', 'S_COVID_BREATH', 'S_COVID_CONFUSION',
       'S_COVID_COUGH', 'S_COVID_FATIGUE', 'S_COVID_FEVER', 'S_COVID_PAIN',
       'S_COVID_BLUISH', 'class4']]
data2 = data[['time_of_day','bpm', 'meanrr', 'mxdmn', 'sdnn',
       'rmssd', 'pnn50', 'mode', 'amo', 'lf', 'hf', 'vlf', 'lfhf',
       'total_power', 'day_after_test', 'class4']]

data3 = data[['bpm', 'meanrr', 'mxdmn', 'sdnn',
       'rmssd', 'pnn50', 'mode', 'amo', 'lf', 'hf', 'vlf', 'lfhf',
       'total_power', 'class4']]

# %% [markdown]
# ### Point Data and Sequence Data

# %%
N, T, C= 1489, 100, 4

##Point Features:
rr_features = pd.DataFrame({'rr_var' : []}) 
#Variance: the average of the squared differences from the mean
rr_features['rr_var'] = rrdata.drop(['user_code','time_of_day','S_COVID_OVERALL','day_after_test'],axis=1).var(axis=1)
#Skewness, a measure of symmetry:
rr_features['rr_skew'] = rrdata.drop(['user_code','time_of_day','S_COVID_OVERALL','day_after_test'],axis=1).skew(axis=1)
#Kurtosis: How heavily the tails of a distribution differ from the tails of a normal distribution:
rr_features['rr_kurt'] = rrdata.drop(['user_code','time_of_day','S_COVID_OVERALL','day_after_test'],axis=1).kurtosis(axis=1)

ori_point_features = data1.drop(['class4'], axis=1) #original point features
Pointdata = torch.tensor(pd.concat([ori_point_features, rr_features],axis=1).values).to(torch.float) #(1489, 25)
Pointdata = (Pointdata-Pointdata.min(0, keepdim=True).values)/(Pointdata.max(0, keepdim=True).values - Pointdata.min(0, keepdim=True).values) #Rescale 


##Sequence Features:  
rr_diff = rrdata.drop(['user_code','time_of_day','S_COVID_OVERALL','day_after_test'],axis=1).diff(periods=-1, axis=1)*(-1) 
rr_diff['rr99'] = 1/3*(rr_diff['rr98'] + rr_diff['rr97'] + rr_diff['rr96'])
rr_diff_tensor = torch.tensor(rr_diff.values).to(torch.float)
rr_diff_tensor = (rr_diff_tensor-rr_diff_tensor.min(0, keepdim=True).values)/(rr_diff_tensor.max(0, keepdim=True).values - rr_diff_tensor.min(0, keepdim=True).values) #Rescale 
rr_diff_tensor = rr_diff_tensor.reshape(N,T,1)

rr = rrdata.drop(['user_code','time_of_day','S_COVID_OVERALL','day_after_test'],axis=1) #original seq features
rr_tensor = torch.tensor(rr.values).to(torch.float)
rr_tensor = (rr_tensor-rr_tensor.min(0, keepdim=True).values)/(rr_tensor.max(0, keepdim=True).values - rr_tensor.min(0, keepdim=True).values) #Rescale 
rr_tensor = rr_tensor.reshape(N,T,1)
Seqdata = torch.cat((rr_tensor, rr_diff_tensor), 2) #(1489, 100, 2)

##Class label:  
class_y = torch.tensor(data1['class4'].values)  #(N=1489, )

print("Pointdata:", Pointdata.shape, Pointdata.dtype)
print("Seqdata:", Seqdata.shape, Seqdata.dtype)
print("class_y:", class_y.shape, class_y.dtype)
# Out:
# Pointdata: torch.Size([1489, 25]) torch.float32
# Seqdata: torch.Size([1489, 100, 2]) torch.float32
# class_y: torch.Size([1489]) torch.int64

# %% [markdown]
# ### LSTM

# %%
def lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b, attn=None, Wattn=None):
    """
    Forward pass for a single timestep of an LSTM.

    The input data has dimension D(number of sequences is D), the hidden state has dimension H=1, and we use
    a minibatch size of N.

    Inputs:
    - x: Input data, of shape (N, D)
    - prev_h: Previous hidden state, of shape (N, H=1)
    - prev_c: previous cell state, of shape (N, H=1)
    - Wx: Input-to-hidden weights, of shape (D, 4H=4)
    - Wh: Hidden-to-hidden weights, of shape (H=1, 4H=4)
    - b: Biases, of shape (4H=4,)      
    
    Returns a tuple of:
    - next_h: Next hidden state, of shape (N, H)
    - next_c: Next cell state, of shape (N, H)
    """
    next_h, next_c = None, None
    N,D = x.shape 
    N,H = prev_h.shape
    A = x.mm(Wx) +  prev_h.mm(Wh)  + b 
    a_i , a_f, a_o, a_g =  A[:,0:H], A[:,H:2*H], A[:,2*H:3*H], A[:,3*H:4*H]
    i, f, o, g = torch.sigmoid(a_i),torch.sigmoid(a_f),torch.sigmoid(a_o), torch.tanh(a_g)
    next_c = f * prev_c + i * g 
    next_h = o * torch.tanh(next_c)
    return next_h, next_c

# %%
def lstm_forward(x, h0, Wx, Wh, b, outT):
    """
    Forward pass for an LSTM over an entire sequence of data. We assume an input
    sequence composed of T vectors, each of dimension D. The LSTM uses a hidden
    size of H=1, and we work over a minibatch containing N sequences. After running
    the LSTM forward, we return the hidden states for all timesteps.

    Inputs:
    - x: Input data, of shape (N, T, D)
    - h0: Initial hidden state, of shape (N, D)
    - Wx: Weights for input-to-hidden connections, of shape (D, 4H=4)
    - Wh: Weights for hidden-to-hidden connections, of shape (H, 4H=4)
    - b: Biases, of shape (4H=4,)
    - outT: how many timesteps returned of the hidden states

    Returns a tuple of:
    - h: Hidden states for all timesteps of all sequences, of shape (N, T, H=1)
    """
    h = None
    c0 = torch.zeros_like(h0) #the intial cell state c0 
    N, T, D = x.shape
    H = Wh.shape[0]
    h = torch.zeros(N, T, H , **to_float_cuda)
    prev_h = h0
    prev_c = c0 
    for t in range(T):
      A = x[:, t, :].mm(Wx) +  prev_h.mm(Wh) + b 
      a_i , a_f, a_o, a_g =  A[:,0:H], A[:,H:2*H], A[:,2*H:3*H], A[:,3*H:4*H]
      i, f, o, g = torch.sigmoid(a_i), torch.sigmoid(a_f), torch.sigmoid(a_o), torch.tanh(a_g)
      next_c = f * prev_c + i * g 
      next_h = o * torch.tanh(next_c)
      h[:, t, :] = next_h        
      prev_h, prev_c = next_h , next_c
    outIndex = [int(i) for i in np.linspace(0,100,num=outT+1,endpoint=False,retstep=True)[0][1:]] #len = outT
    h = h[:, outIndex, :]  #(N, outT, H)
    return h

# %% [markdown]
# ### Loss

# %%
def softmax_loss(x, y):
    """
    Inputs:
    - x: Input scores, of shape (N, C=4) 
    - y: Ground-truth indices, of shape (N, ) where each element is in the range 1 <= y[i] <= 4

    Returns:
    - loss: Scalar giving loss
    """
    loss = None    
    N, C = x.shape[0], x.shape[1]  
    loss = F.cross_entropy(x, y, reduction='sum') * 1. / N   
    return loss

# %% [markdown]
# ### RNN-DNN Model

# %%
class RNN_DNN(nn.Module):
    def __init__(self, input_dim=1, input_dim_v=4, input_dim_t=100, C=4, hidden_dim=1, proj_dim=1, 
                 DNN_hidden_Size=[10,5], reg=0.0, cell_type='lstm', dropratio=0.5, device='cuda', dtype=torch.float):
        """
        Inputs:
        - input_dim: Dimension D of input(number of sequence) 
        - input_dim_v: number of point features
        - input_dim_t: length of time for sequence features 
        - C: number of classes 
        - hidden_dim: Dimension H for the hidden state of the RNN.
        - DNN_hidden_Size: list, dimension of DNN hidden layers
        - reg: regularization parameter
        - cell_type: What type of RNN to use: 'lstm'
        - device: 'cuda' or 'cpu'
        - dtype: datatype to use
        """
        super().__init__()
        if cell_type not in {'rnn', 'lstm'}:
            raise ValueError('Invalid cell_type "%s"' % cell_type)
        
        self.input_dim = input_dim
        self.H = hidden_dim
        self.V = input_dim_v
        self.T = input_dim_t
        self.C = C 
        self.P = proj_dim
        self.DNN_hidden_Size = DNN_hidden_Size
        self.dtype = dtype
        self.device = device
        self.cell_type = cell_type
        self.reg = reg 
        self.dropratio = dropratio

        # Initialize parameters for the RNN / LSTM  
        fac = {'rnn':1, 'lstm':4}[self.cell_type]
        self.Wx = Parameter(torch.randn(input_dim, fac * self.H, device=device, dtype=dtype).div(math.sqrt(input_dim)))
        self.Wh = Parameter(torch.randn(self.H, fac * self.H, device=device, dtype=dtype).div(math.sqrt(self.H)))
        self.b = Parameter(torch.zeros(fac * self.H, device=device, dtype=dtype))

        #Initialize RNN output multi-state(N,T,H=1) -> single state(N,H=1) projection parameters: 
        self.W_proj = Parameter(torch.randn(self.T, self.P, device=device, dtype=dtype).div(math.sqrt(input_dim)))
        self.b_proj = Parameter(torch.zeros(self.P, device=device, dtype=dtype))

        #Initialize parameters for DNN 
        W_d1 = Parameter(torch.randn(self.V+self.P, self.DNN_hidden_Size[0], device=device, dtype=dtype).div(math.sqrt(self.V + self.P)))
        exec(f'self.W_d{1} = W_d1') 
        b_d1 = Parameter(torch.zeros(self.DNN_hidden_Size[0], device=device, dtype=dtype))
        exec(f'self.b_d{1} = b_d1') 
        for i in range(2,len(self.DNN_hidden_Size)+1):
          W_di = Parameter(torch.randn(self.DNN_hidden_Size[i-2], self.DNN_hidden_Size[i-1], device=device, dtype=dtype).div(math.sqrt(self.DNN_hidden_Size[i-2])))
          exec(f'self.W_d{i} = W_di')   
          b_di = Parameter(torch.zeros(self.DNN_hidden_Size[i-1], device=device, dtype=dtype)) 
          exec(f'self.b_d{i} = b_di')   
        W_dlast = Parameter(torch.randn(self.DNN_hidden_Size[-1], self.C, device=device, dtype=dtype).div(math.sqrt(self.DNN_hidden_Size[-1])))
        exec(f'self.W_d{len(self.DNN_hidden_Size)+1} = W_dlast')   
        b_dlast = Parameter(torch.zeros(self.C, device=device, dtype=dtype))
        exec(f'self.b_d{len(self.DNN_hidden_Size)+1} = b_dlast')   
 
    
    def train_process(self):
      raise NotImplementedError
    
    def test_process(self):
      raise NotImplementedError
    
    def UQ_test_process(self):
      raise NotImplementedError

# %%
    def RNN_DNN_forward(self, Pointdata, Seqdata, y):
        """
        Inputs:
        - Pointdata: (N, V) 
        - Seqdata: (N, T, D)
        - y: (N,)

        Outputs:
        - loss: A scalar loss
        """

        loss = 0.0
        Pointdata = Pointdata.to(self.device)  #(N,V)
        Seqdata = Seqdata.to(self.device)
        groundTruth_y = y.to(torch.long).to(self.device) #(N,)

        #(1) h0
        A0 = Seqdata[:,0,:].mm(self.Wx) #(N,4H)
        h0 =  A0[:,0:self.H] + A0[:,self.H:2*self.H] + A0[:,2*self.H:3*self.H] + A0[:,3*self.H:4*self.H]


        #(2) multi-state(hidden state)
        if self.cell_type == 'lstm':
          hidden_state = lstm_forward(Seqdata, h0, self.Wx, self.Wh, self.b, self.T)   #(N,T,H=1) 

        N = Pointdata.shape[0]
        H = self.H
        T = self.T

        #(3) single state 
        single_state = hidden_state.reshape(N, T*H).mm(self.W_proj)+self.b_proj  #(N,P)  
        single_state = F.dropout(single_state, p=self.dropratio) 

        #(4) DNN 
        DNNInput = torch.cat((Pointdata, single_state), 1)  #(N, V+P)
        DNNhidden = DNNInput.mm(self.W_d1)+self.b_d1  
        DNNhidden = torch.sigmoid(DNNhidden)
        DNNhidden = F.dropout(DNNhidden, p=self.dropratio)
        for i in range(2,len(self.DNN_hidden_Size)+1):
          DNNhidden = DNNhidden.mm(eval('self.W_d'+str(i))) + eval('self.b_d'+str(i))
          DNNhidden = F.leaky_relu(DNNhidden, negative_slope=0.01) # DNNhidden = torch.relu(DNNhidden)  #
          DNNhidden = F.dropout(DNNhidden, p=self.dropratio) 
        DNNoutput = DNNhidden.mm(eval('self.W_d'+str(len(self.DNN_hidden_Size)+1))) + eval('self.b_d'+str(len(self.DNN_hidden_Size)+1))  

        #(5)
        loss = softmax_loss(DNNoutput, groundTruth_y)
        loss +=self.reg * torch.sum(self.Wx*self.Wx) + self.reg * torch.sum(self.Wh*self.Wh) #regularization 
        loss +=self.reg * torch.sum(self.W_proj*self.W_proj) #regularization 
      
        return loss

    RNN_DNN.train_process = RNN_DNN_forward

# %%
    def RNN_DNN_test(self, Pointdata, Seqdata, y):
        """
        Inputs:
        - Pointdata: (N, V) 
        - Seqdata: (N, T, D)

        Outputs:
        - scalar: classficition 
        """

        Pointdata = Pointdata.to(self.device)  #(N,V)
        Seqdata = Seqdata.to(self.device)
        groundTruth_y = y.to(torch.long).to(self.device) #(N,)

        #(1) h0
        A0 = Seqdata[:,0,:].mm(self.Wx) #(N,4H)
        h0 =  A0[:,0:self.H] + A0[:,self.H:2*self.H] + A0[:,2*self.H:3*self.H] + A0[:,3*self.H:4*self.H]

        #(2) multi-state(hidden state)
        if self.cell_type == 'lstm':
          hidden_state = lstm_forward(Seqdata, h0, self.Wx, self.Wh, self.b, self.T)   #(N,T,H=1) 
       
        N = Pointdata.shape[0]
        H = self.H 
        T = self.T
        
        #(3) single state 
        single_state = hidden_state.reshape(N, T*H).mm(self.W_proj)+self.b_proj  #(N,P)  

        #(4) DNN 
        DNNInput = torch.cat((Pointdata, single_state), 1)  #(N, V+P)
        DNNhidden = DNNInput.mm(self.W_d1)+self.b_d1  
        DNNhidden = torch.sigmoid(DNNhidden)
        for i in range(2,len(self.DNN_hidden_Size)+1):
          DNNhidden = DNNhidden.mm(eval('self.W_d'+str(i))) + eval('self.b_d'+str(i))
          DNNhidden = F.leaky_relu(DNNhidden, negative_slope=0.01)  #DNNhidden = torch.relu(DNNhidden) 
        DNNoutput = DNNhidden.mm(eval('self.W_d'+str(len(self.DNN_hidden_Size)+1))) + eval('self.b_d'+str(len(self.DNN_hidden_Size)+1))  
                
        #(5)
        pred_y = DNNoutput.argmax(dim=1)
    
        return  pred_y

    RNN_DNN.test_process = RNN_DNN_test

# %% [markdown]
# ### Training

# %%
def ModelTrain(rnndnn_model, Point_data, Seq_data, y_data, lr_decay=1, **kwargs):
  """
  Run optimization to train the model.
  """
  # optimizer setup
  from torch import optim
  optimizer = optim.Adam(
    filter(lambda p: p.requires_grad, rnndnn_model.parameters()), learning_rate) # leave betas and eps by default
  lr_scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda epoch: lr_decay ** epoch)

  # sample minibatch data
  iter_per_epoch = math.ceil(Point_data.shape[0] // batch_size)
  loss_history = []
  rnndnn_model.train()
  for i in range(num_epochs):
    start_t = time.time()
    for j in range(iter_per_epoch):
      PointData = Point_data[j*batch_size:(j+1)*batch_size]
      SeqData =  Seq_data[j*batch_size:(j+1)*batch_size]
      y = y_data[j*batch_size:(j+1)*batch_size]

      loss = rnndnn_model.train_process(PointData, SeqData, y)
      optimizer.zero_grad() 
      loss.backward()
      loss_history.append(loss.item())
      optimizer.step()
    end_t = time.time()
    print('(Epoch {} / {}) loss: {:.4f} time per epoch: {:.1f}s'.format(i, num_epochs, loss.item(), end_t-start_t))
    lr_scheduler.step()

  # plot the training losses
  plt.plot(loss_history, color='black')
  plt.xlabel('Iteration')
  plt.ylabel('Loss')
  plt.title('Training loss history')
  plt.show()

# %%
from sklearn.model_selection import train_test_split
Pointdata_train, Pointdata_test, Seqdata_train, Seqdata_test, class_y_train, class_y_test = train_test_split(Pointdata, Seqdata, class_y, test_size=0.2, random_state=6)

Pointdata_train, Pointdata_test = Pointdata_train.to(torch.float), Pointdata_test.to(torch.float)
Seqdata_train, Seqdata_test = Seqdata_train.to(torch.float), Seqdata_test.to(torch.float)

#Pointdata_train, Pointdata_test = Pointdata_train.to(torch.float), Pointdata_test.to(torch.float)
#Seqdata_train, Seqdata_test = Seqdata_train.to(torch.float), Seqdata_test.to(torch.float)

print("Pointdata_train:", Pointdata_train.shape, Pointdata_train.dtype)  #(1191, 25)
print("Pointdata_test:", Pointdata_test.shape, Pointdata_test.dtype)     #(298, 25)
print("Seqdata_train:", Seqdata_train.shape, Seqdata_train.dtype)        #(1191, 100, 2)
print("Seqdata_test:", Seqdata_test.shape, Seqdata_test.dtype)           #(298, 100, 2)
print("class_y_train:", class_y_train.shape, class_y_train.dtype)        #(1191,) 
print("class_y_test:", class_y_test.shape, class_y_test.dtype)           #(298, )
# Out:
# Pointdata_train: torch.Size([1191, 25]) torch.float32
# Pointdata_test: torch.Size([298, 25]) torch.float32
# Seqdata_train: torch.Size([1191, 100, 2]) torch.float32
# Seqdata_test: torch.Size([298, 100, 2]) torch.float32
# class_y_train: torch.Size([1191]) torch.int64
# class_y_test: torch.Size([298]) torch.int64

# %% [markdown]
# ################################################################
# #  UQ
# ################################################################

# %%
def RNN_DNN_test_UQ(self, Pointdata, Seqdata):
      """
      Inputs:
      - Pointdata: (N, V) 
      - Seqdata: (N, T, D)

      Outputs:
      - scalar: classficition 
      """

      Pointdata = Pointdata.to(self.device)  #(N,V)
      Seqdata = Seqdata.to(self.device)

      #(1) h0
      A0 = Seqdata[:,0,:].mm(self.Wx) #(N,4H)
      h0 =  A0[:,0:self.H] + A0[:,self.H:2*self.H] + A0[:,2*self.H:3*self.H] + A0[:,3*self.H:4*self.H]

      #(2) multi-state(hidden state)
      if self.cell_type == 'lstm':
        hidden_state = lstm_forward(Seqdata, h0, self.Wx, self.Wh, self.b, self.T)   #(N,T,H=1) 
      
      N = Pointdata.shape[0]
      H = self.H 
      T = self.T
      
      #(3) single state 
      single_state = hidden_state.reshape(N, T*H).mm(self.W_proj)+self.b_proj  #(N,P)  

      #(4) DNN 
      DNNInput = torch.cat((Pointdata, single_state), 1)  #(N, V+P)
      DNNhidden = DNNInput.mm(self.W_d1)+self.b_d1  
      DNNhidden = torch.sigmoid(DNNhidden)
      for i in range(2,len(self.DNN_hidden_Size)+1):
        DNNhidden = DNNhidden.mm(eval('self.W_d'+str(i))) + eval('self.b_d'+str(i))
        DNNhidden = F.leaky_relu(DNNhidden, negative_slope=0.01)  
      DNNoutput = DNNhidden.mm(eval('self.W_d'+str(len(self.DNN_hidden_Size)+1))) + eval('self.b_d'+str(len(self.DNN_hidden_Size)+1))  

      #(5)
      pred_y = DNNoutput.argmax(dim=1)
      pred_y_prob = F.softmax(DNNoutput, dim=1)
      return pred_y, pred_y_prob

RNN_DNN.UQ_test_process = RNN_DNN_test_UQ

# %%
#bootstrap sample
import random
B=50
probB = torch.empty(1, 298, 4)  #initialize probability training set 
probB_train = torch.empty(1, 1191, 4)  #initialize probability test set

for b in range(B):
  print('------------------------- Bootstrip %s ------------------------'%(b) )
  index_b = random.choices(range(Pointdata_train.shape[0]) , k=Pointdata_train.shape[0])
  Pointdata_train_b = Pointdata_train[index_b]
  Seqdata_train_b = Seqdata_train[index_b]
  class_y_train_b = class_y_train[index_b]

  num_epochs = 1500
  batch_size = 1191 
  learning_rate = 1e-3
  rnn_dnn_model_UQ = RNN_DNN( 
            cell_type='lstm',
            input_dim = 2,     #Seqdata_train.shape[2]
            input_dim_v = 25,  #Pointdata_train.shape[1],
            input_dim_t= 50,   #Seqdata_train.shape[1], 
            proj_dim = 10,
            C=4, 
            hidden_dim = 1, 
            reg = 0.0, 
            dropratio = 0.5, 
            DNN_hidden_Size=[256, 1024, 2048, 1024, 512],  #str11
            **to_float_cuda)

  print('learning rate is: ', learning_rate)
  ModelTrain(rnn_dnn_model_UQ, Pointdata_train_b, Seqdata_train_b, class_y_train_b,
                  num_epochs=num_epochs, batch_size=batch_size,
                  learning_rate=learning_rate)

  rnn_dnn_model_UQ = rnn_dnn_model_UQ.eval()  
  y_pred_train_b, y_pred_prob_train_b = rnn_dnn_model_UQ.UQ_test_process(Pointdata_train_b, Seqdata_train_b)
  y_pred_train_b, y_pred_prob_train_b = y_pred_train_b.to('cpu'), y_pred_prob_train_b.to('cpu')
  y_pred_b, y_pred_prob_b = rnn_dnn_model_UQ.UQ_test_process(Pointdata_test, Seqdata_test)
  y_pred_b, y_pred_prob_b = y_pred_b.to('cpu'), y_pred_prob_b.to('cpu')

  probB = torch.cat([probB, y_pred_prob_b.data.reshape(1,298,4)], dim = 0)
  probB_train = torch.cat([probB_train, y_pred_prob_train_b.data.reshape(1,1191,4)], dim=0)

probB = probB[1:,:,:]  # remove the initialized prob
probB_train = probB_train[1:,:,:] # remove the initialized prob
# Out:
# ------------------------- Bootstrip 0 ------------------------
# learning rate is:  0.001
# (Epoch 0 / 1500) loss: 1.5495 time per epoch: 0.1s
# (Epoch 1 / 1500) loss: 2.6565 time per epoch: 0.1s
# (Epoch 2 / 1500) loss: 1.4634 time per epoch: 0.1s
# (Epoch 3 / 1500) loss: 1.4184 time per epoch: 0.1s
# (Epoch 4 / 1500) loss: 1.4152 time per epoch: 0.1s
# (Epoch 5 / 1500) loss: 1.4207 time per epoch: 0.1s
# (Epoch 6 / 1500) loss: 1.3929 time per epoch: 0.1s
# (Epoch 7 / 1500) loss: 1.3769 time per epoch: 0.1s
# (Epoch 8 / 1500) loss: 1.3706 time per epoch: 0.1s
# (Epoch 9 / 1500) loss: 1.3737 time per epoch: 0.1s
# (Epoch 10 / 1500) loss: 1.3630 time per epoch: 0.1s
# (Epoch 11 / 1500) loss: 1.3667 time per epoch: 0.1s
# (Epoch 12 / 1500) loss: 1.3623 time per epoch: 0.1s
# (Epoch 13 / 1500) loss: 1.3743 time per epoch: 0.1s
# (Epoch 14 / 1500) loss: 1.3658 time per epoch: 0.1s
# (Epoch 15 / 1500) loss: 1.3647 time per epoch: 0.1s
# (Epoch 16 / 1500) loss: 1.3605 time per epoch: 0.1s
# (Epoch 17 / 1500) loss: 1.3626 time per epoch: 0.1s
# (Epoch 18 / 1500) loss: 1.3613 time per epoch: 0.1s
# (Epoch 19 / 1500) loss: 1.3624 time per epoch: 0.1s
# (Epoch 20 / 1500) loss: 1.3586 time per epoch: 0.1s
# (Epoch 21 / 1500) loss: 1.3560 time per epoch: 0.1s
# (Epoch 22 / 1500) loss: 1.3588 time per epoch: 0.1s
# (Epoch 23 / 1500) loss: 1.3592 time per epoch: 0.1s
# (Epoch 24 / 1500) loss: 1.3583 time per epoch: 0.1s
# (Epoch 25 / 1500) loss: 1.3588 time per epoch: 0.1s
# (Epoch 26 / 1500) loss: 1.3549 time per epoch: 0.1s
# (Epoch 27 / 1500) loss: 1.3587 time per epoch: 0.1s
# (Epoch 28 / 1500) loss: 1.3610 time per epoch: 0.1s
# (Epoch 29 / 1500) loss: 1.3568 time per epoch: 0.1s
# (Epoch 30 / 1500) loss: 1.3619 time per epoch: 0.1s
# (Epoch 31 / 1500) loss: 1.3631 time per epoch: 0.1s
# (Epoch 32 / 1500) loss: 1.3573 time per epoch: 0.1s
# (Epoch 33 / 1500) loss: 1.3595 time per epoch: 0.1s
# (Epoch 34 / 1500) loss: 1.3613 time per epoch: 0.1s
# (Epoch 35 / 1500) loss: 1.3577 time per epoch: 0.1s
# (Epoch 36 / 1500) loss: 1.3559 time per epoch: 0.1s
# (Epoch 37 / 1500) loss: 1.3600 time per epoch: 0.1s
# (Epoch 38 / 1500) loss: 1.3591 time per epoch: 0.1s
# (Epoch 39 / 1500) loss: 1.3552 time per epoch: 0.1s
# (Epoch 40 / 1500) loss: 1.3602 time per epoch: 0.1s
# (Epoch 41 / 1500) loss: 1.3587 time per epoch: 0.1s
# (Epoch 42 / 1500) loss: 1.3500 time per epoch: 0.1s
# (Epoch 43 / 1500) loss: 1.3551 time per epoch: 0.1s
# (Epoch 44 / 1500) loss: 1.3524 time per epoch: 0.1s
# (Epoch 45 / 1500) loss: 1.3555 time per epoch: 0.1s
# (Epoch 46 / 1500) loss: 1.3538 time per epoch: 0.1s
# (Epoch 47 / 1500) loss: 1.3568 time per epoch: 0.1s
# (Epoch 48 / 1500) loss: 1.3583 time per epoch: 0.1s
# (Epoch 49 / 1500) loss: 1.3562 time per epoch: 0.1s
# (Epoch 50 / 1500) loss: 1.3522 time per epoch: 0.1s
# (Epoch 51 / 1500) loss: 1.3514 time per epoch: 0.1s
# (Epoch 52 / 1500) loss: 1.3571 time per epoch: 0.1s
# (Epoch 53 / 1500) loss: 1.3556 time per epoch: 0.1s
# (Epoch 54 / 1500) loss: 1.3486 time per epoch: 0.1s
# (Epoch 55 / 1500) loss: 1.3467 time per epoch: 0.1s
# (Epoch 56 / 1500) loss: 1.3518 time per epoch: 0.1s
# (Epoch 57 / 1500) loss: 1.3508 time per epoch: 0.1s
# (Epoch 58 / 1500) loss: 1.3452 time per epoch: 0.1s
# (Epoch 59 / 1500) loss: 1.3472 time per epoch: 0.1s
# (Epoch 60 / 1500) loss: 1.3499 time per epoch: 0.1s
# (Epoch 61 / 1500) loss: 1.3507 time per epoch: 0.1s
# (Epoch 62 / 1500) loss: 1.3403 time per epoch: 0.1s
# (Epoch 63 / 1500) loss: 1.3395 time per epoch: 0.1s
# (Epoch 64 / 1500) loss: 1.3454 time per epoch: 0.1s
# (Epoch 65 / 1500) loss: 1.3338 time per epoch: 0.1s
# (Epoch 66 / 1500) loss: 1.3263 time per epoch: 0.1s
# (Epoch 67 / 1500) loss: 1.3449 time per epoch: 0.1s
# (Epoch 68 / 1500) loss: 1.3262 time per epoch: 0.1s
# (Epoch 69 / 1500) loss: 1.3308 time per epoch: 0.1s
# (Epoch 70 / 1500) loss: 1.3265 time per epoch: 0.1s
# (Epoch 71 / 1500) loss: 1.3174 time per epoch: 0.1s
# (Epoch 72 / 1500) loss: 1.3124 time per epoch: 0.1s
# (Epoch 73 / 1500) loss: 1.3277 time per epoch: 0.1s
# (Epoch 74 / 1500) loss: 1.3166 time per epoch: 0.1s
# (Epoch 75 / 1500) loss: 1.3095 time per epoch: 0.1s
# (Epoch 76 / 1500) loss: 1.3122 time per epoch: 0.1s
# (Epoch 77 / 1500) loss: 1.3068 time per epoch: 0.1s
# (Epoch 78 / 1500) loss: 1.2969 time per epoch: 0.1s
# (Epoch 79 / 1500) loss: 1.3151 time per epoch: 0.1s
# (Epoch 80 / 1500) loss: 1.2843 time per epoch: 0.1s
# (Epoch 81 / 1500) loss: 1.3011 time per epoch: 0.1s
# (Epoch 82 / 1500) loss: 1.2986 time per epoch: 0.1s
# (Epoch 83 / 1500) loss: 1.2932 time per epoch: 0.1s
# (Epoch 84 / 1500) loss: 1.3018 time per epoch: 0.1s
# (Epoch 85 / 1500) loss: 1.2901 time per epoch: 0.1s
# (Epoch 86 / 1500) loss: 1.2817 time per epoch: 0.1s
# (Epoch 87 / 1500) loss: 1.2928 time per epoch: 0.1s
# (Epoch 88 / 1500) loss: 1.2923 time per epoch: 0.1s
# (Epoch 89 / 1500) loss: 1.2690 time per epoch: 0.1s
# (Epoch 90 / 1500) loss: 1.2888 time per epoch: 0.1s
# (Epoch 91 / 1500) loss: 1.2744 time per epoch: 0.1s
# (Epoch 92 / 1500) loss: 1.2570 time per epoch: 0.1s
# (Epoch 93 / 1500) loss: 1.2756 time per epoch: 0.1s
# (Epoch 94 / 1500) loss: 1.2646 time per epoch: 0.1s
# (Epoch 95 / 1500) loss: 1.2555 time per epoch: 0.1s
# (Epoch 96 / 1500) loss: 1.2501 time per epoch: 0.1s
# (Epoch 97 / 1500) loss: 1.2426 time per epoch: 0.1s
# (Epoch 98 / 1500) loss: 1.2678 time per epoch: 0.1s
# (Epoch 99 / 1500) loss: 1.2698 time per epoch: 0.1s
# (Epoch 100 / 1500) loss: 1.2471 time per epoch: 0.1s
# (Epoch 101 / 1500) loss: 1.2489 time per epoch: 0.1s
# (Epoch 102 / 1500) loss: 1.2478 time per epoch: 0.1s
# (Epoch 103 / 1500) loss: 1.2383 time per epoch: 0.1s
# (Epoch 104 / 1500) loss: 1.2354 time per epoch: 0.1s
# (Epoch 105 / 1500) loss: 1.2375 time per epoch: 0.1s
# (Epoch 106 / 1500) loss: 1.2311 time per epoch: 0.1s
# (Epoch 107 / 1500) loss: 1.2462 time per epoch: 0.1s
# (Epoch 108 / 1500) loss: 1.2356 time per epoch: 0.1s
# (Epoch 109 / 1500) loss: 1.2445 time per epoch: 0.1s
# (Epoch 110 / 1500) loss: 1.2351 time per epoch: 0.1s
# (Epoch 111 / 1500) loss: 1.2365 time per epoch: 0.1s
# (Epoch 112 / 1500) loss: 1.2420 time per epoch: 0.1s
# (Epoch 113 / 1500) loss: 1.2213 time per epoch: 0.1s
# (Epoch 114 / 1500) loss: 1.2252 time per epoch: 0.1s
# (Epoch 115 / 1500) loss: 1.2083 time per epoch: 0.1s
# (Epoch 116 / 1500) loss: 1.2115 time per epoch: 0.1s
# (Epoch 117 / 1500) loss: 1.2214 time per epoch: 0.1s
# (Epoch 118 / 1500) loss: 1.2101 time per epoch: 0.1s
# (Epoch 119 / 1500) loss: 1.2091 time per epoch: 0.1s
# (Epoch 120 / 1500) loss: 1.2092 time per epoch: 0.1s
# (Epoch 121 / 1500) loss: 1.2159 time per epoch: 0.1s
# (Epoch 122 / 1500) loss: 1.2071 time per epoch: 0.1s
# (Epoch 123 / 1500) loss: 1.2018 time per epoch: 0.1s
# (Epoch 124 / 1500) loss: 1.2059 time per epoch: 0.1s
# (Epoch 125 / 1500) loss: 1.1965 time per epoch: 0.1s
# (Epoch 126 / 1500) loss: 1.2085 time per epoch: 0.1s
# (Epoch 127 / 1500) loss: 1.1831 time per epoch: 0.1s
# (Epoch 128 / 1500) loss: 1.1841 time per epoch: 0.1s
# (Epoch 129 / 1500) loss: 1.2075 time per epoch: 0.1s
# (Epoch 130 / 1500) loss: 1.1915 time per epoch: 0.1s
# (Epoch 131 / 1500) loss: 1.1920 time per epoch: 0.1s
# (Epoch 132 / 1500) loss: 1.1933 time per epoch: 0.1s
# (Epoch 133 / 1500) loss: 1.1810 time per epoch: 0.1s
# (Epoch 134 / 1500) loss: 1.1929 time per epoch: 0.1s
# (Epoch 135 / 1500) loss: 1.1800 time per epoch: 0.1s
# (Epoch 136 / 1500) loss: 1.1790 time per epoch: 0.1s
# (Epoch 137 / 1500) loss: 1.1780 time per epoch: 0.1s
# (Epoch 138 / 1500) loss: 1.1686 time per epoch: 0.1s
# (Epoch 139 / 1500) loss: 1.1852 time per epoch: 0.1s
# (Epoch 140 / 1500) loss: 1.1607 time per epoch: 0.1s
# (Epoch 141 / 1500) loss: 1.1831 time per epoch: 0.1s
# (Epoch 142 / 1500) loss: 1.1785 time per epoch: 0.1s
# (Epoch 143 / 1500) loss: 1.1704 time per epoch: 0.1s
# (Epoch 144 / 1500) loss: 1.1637 time per epoch: 0.1s
# (Epoch 145 / 1500) loss: 1.1757 time per epoch: 0.1s
# (Epoch 146 / 1500) loss: 1.1803 time per epoch: 0.1s
# (Epoch 147 / 1500) loss: 1.1347 time per epoch: 0.1s
# (Epoch 148 / 1500) loss: 1.1668 time per epoch: 0.1s
# (Epoch 149 / 1500) loss: 1.1713 time per epoch: 0.1s
# (Epoch 150 / 1500) loss: 1.1843 time per epoch: 0.1s
# (Epoch 151 / 1500) loss: 1.1558 time per epoch: 0.1s
# (Epoch 152 / 1500) loss: 1.1600 time per epoch: 0.1s
# (Epoch 153 / 1500) loss: 1.1442 time per epoch: 0.1s
# (Epoch 154 / 1500) loss: 1.1591 time per epoch: 0.1s
# (Epoch 155 / 1500) loss: 1.1493 time per epoch: 0.1s
# (Epoch 156 / 1500) loss: 1.1618 time per epoch: 0.1s
# (Epoch 157 / 1500) loss: 1.1542 time per epoch: 0.1s
# (Epoch 158 / 1500) loss: 1.1555 time per epoch: 0.1s
# (Epoch 159 / 1500) loss: 1.1506 time per epoch: 0.1s
# (Epoch 160 / 1500) loss: 1.1450 time per epoch: 0.1s
# (Epoch 161 / 1500) loss: 1.1357 time per epoch: 0.1s
# (Epoch 162 / 1500) loss: 1.1401 time per epoch: 0.1s
# (Epoch 163 / 1500) loss: 1.1573 time per epoch: 0.1s
# (Epoch 164 / 1500) loss: 1.1442 time per epoch: 0.1s
# (Epoch 165 / 1500) loss: 1.1341 time per epoch: 0.1s
# (Epoch 166 / 1500) loss: 1.1335 time per epoch: 0.1s
# (Epoch 167 / 1500) loss: 1.1487 time per epoch: 0.1s
# (Epoch 168 / 1500) loss: 1.1397 time per epoch: 0.1s
# (Epoch 169 / 1500) loss: 1.1284 time per epoch: 0.1s
# (Epoch 170 / 1500) loss: 1.1306 time per epoch: 0.1s
# (Epoch 171 / 1500) loss: 1.1257 time per epoch: 0.1s
# (Epoch 172 / 1500) loss: 1.1361 time per epoch: 0.1s
# (Epoch 173 / 1500) loss: 1.1239 time per epoch: 0.1s
# (Epoch 174 / 1500) loss: 1.1342 time per epoch: 0.1s
# (Epoch 175 / 1500) loss: 1.1336 time per epoch: 0.1s
# (Epoch 176 / 1500) loss: 1.1314 time per epoch: 0.1s
# (Epoch 177 / 1500) loss: 1.1129 time per epoch: 0.1s
# (Epoch 178 / 1500) loss: 1.1301 time per epoch: 0.1s
# (Epoch 179 / 1500) loss: 1.1197 time per epoch: 0.1s
# (Epoch 180 / 1500) loss: 1.1179 time per epoch: 0.1s
# (Epoch 181 / 1500) loss: 1.1149 time per epoch: 0.1s
# (Epoch 182 / 1500) loss: 1.1052 time per epoch: 0.1s
# (Epoch 183 / 1500) loss: 1.1205 time per epoch: 0.1s
# (Epoch 184 / 1500) loss: 1.1086 time per epoch: 0.1s
# (Epoch 185 / 1500) loss: 1.1192 time per epoch: 0.1s
# (Epoch 186 / 1500) loss: 1.0951 time per epoch: 0.1s
# (Epoch 187 / 1500) loss: 1.0993 time per epoch: 0.1s
# (Epoch 188 / 1500) loss: 1.1081 time per epoch: 0.1s
# (Epoch 189 / 1500) loss: 1.1209 time per epoch: 0.1s
# (Epoch 190 / 1500) loss: 1.0831 time per epoch: 0.1s
# (Epoch 191 / 1500) loss: 1.0951 time per epoch: 0.1s
# (Epoch 192 / 1500) loss: 1.1200 time per epoch: 0.1s
# (Epoch 193 / 1500) loss: 1.0848 time per epoch: 0.1s
# (Epoch 194 / 1500) loss: 1.0943 time per epoch: 0.1s
# (Epoch 195 / 1500) loss: 1.1356 time per epoch: 0.1s
# (Epoch 196 / 1500) loss: 1.0870 time per epoch: 0.1s
# (Epoch 197 / 1500) loss: 1.0891 time per epoch: 0.1s
# (Epoch 198 / 1500) loss: 1.1134 time per epoch: 0.1s
# (Epoch 199 / 1500) loss: 1.0996 time per epoch: 0.1s
# (Epoch 200 / 1500) loss: 1.0814 time per epoch: 0.1s
# (Epoch 201 / 1500) loss: 1.0737 time per epoch: 0.1s
# (Epoch 202 / 1500) loss: 1.0984 time per epoch: 0.1s
# (Epoch 203 / 1500) loss: 1.1016 time per epoch: 0.1s
# (Epoch 204 / 1500) loss: 1.0969 time per epoch: 0.1s
# (Epoch 205 / 1500) loss: 1.0836 time per epoch: 0.1s
# (Epoch 206 / 1500) loss: 1.0741 time per epoch: 0.1s
# (Epoch 207 / 1500) loss: 1.0753 time per epoch: 0.1s
# (Epoch 208 / 1500) loss: 1.0723 time per epoch: 0.1s
# (Epoch 209 / 1500) loss: 1.0817 time per epoch: 0.1s
# (Epoch 210 / 1500) loss: 1.0899 time per epoch: 0.1s
# (Epoch 211 / 1500) loss: 1.0858 time per epoch: 0.1s
# (Epoch 212 / 1500) loss: 1.0962 time per epoch: 0.1s
# (Epoch 213 / 1500) loss: 1.0826 time per epoch: 0.1s
# (Epoch 214 / 1500) loss: 1.0715 time per epoch: 0.1s
# (Epoch 215 / 1500) loss: 1.0580 time per epoch: 0.1s
# (Epoch 216 / 1500) loss: 1.0803 time per epoch: 0.1s
# (Epoch 217 / 1500) loss: 1.0711 time per epoch: 0.1s
# (Epoch 218 / 1500) loss: 1.0655 time per epoch: 0.1s
# (Epoch 219 / 1500) loss: 1.0506 time per epoch: 0.1s
# (Epoch 220 / 1500) loss: 1.0506 time per epoch: 0.1s
# (Epoch 221 / 1500) loss: 1.0501 time per epoch: 0.1s
# (Epoch 222 / 1500) loss: 1.0756 time per epoch: 0.1s
# (Epoch 223 / 1500) loss: 1.0782 time per epoch: 0.1s
# (Epoch 224 / 1500) loss: 1.0431 time per epoch: 0.1s
# (Epoch 225 / 1500) loss: 1.0833 time per epoch: 0.1s
# (Epoch 226 / 1500) loss: 1.0558 time per epoch: 0.1s
# (Epoch 227 / 1500) loss: 1.0656 time per epoch: 0.1s
# (Epoch 228 / 1500) loss: 1.0611 time per epoch: 0.1s
# (Epoch 229 / 1500) loss: 1.0502 time per epoch: 0.1s
# (Epoch 230 / 1500) loss: 1.0676 time per epoch: 0.1s
# (Epoch 231 / 1500) loss: 1.0530 time per epoch: 0.1s
# (Epoch 232 / 1500) loss: 1.0476 time per epoch: 0.1s
# (Epoch 233 / 1500) loss: 1.0448 time per epoch: 0.1s
# (Epoch 234 / 1500) loss: 1.0524 time per epoch: 0.1s
# (Epoch 235 / 1500) loss: 1.0462 time per epoch: 0.1s
# (Epoch 236 / 1500) loss: 1.0396 time per epoch: 0.1s
# (Epoch 237 / 1500) loss: 1.0483 time per epoch: 0.1s
# (Epoch 238 / 1500) loss: 1.0736 time per epoch: 0.1s
# (Epoch 239 / 1500) loss: 1.0259 time per epoch: 0.1s
# (Epoch 240 / 1500) loss: 1.0462 time per epoch: 0.1s
# (Epoch 241 / 1500) loss: 1.0099 time per epoch: 0.1s
# (Epoch 242 / 1500) loss: 1.0499 time per epoch: 0.1s
# (Epoch 243 / 1500) loss: 1.0135 time per epoch: 0.1s
# (Epoch 244 / 1500) loss: 1.0286 time per epoch: 0.1s
# (Epoch 245 / 1500) loss: 1.0309 time per epoch: 0.1s
# (Epoch 246 / 1500) loss: 1.0221 time per epoch: 0.1s
# (Epoch 247 / 1500) loss: 1.0234 time per epoch: 0.1s
# (Epoch 248 / 1500) loss: 1.0325 time per epoch: 0.1s
# (Epoch 249 / 1500) loss: 1.0057 time per epoch: 0.1s
# (Epoch 250 / 1500) loss: 0.9985 time per epoch: 0.1s
# (Epoch 251 / 1500) loss: 1.0135 time per epoch: 0.1s
# (Epoch 252 / 1500) loss: 1.0307 time per epoch: 0.1s
# (Epoch 253 / 1500) loss: 1.0445 time per epoch: 0.1s
# (Epoch 254 / 1500) loss: 0.9874 time per epoch: 0.1s
# (Epoch 255 / 1500) loss: 1.0204 time per epoch: 0.1s
# (Epoch 256 / 1500) loss: 1.0111 time per epoch: 0.1s
# (Epoch 257 / 1500) loss: 1.0237 time per epoch: 0.1s
# (Epoch 258 / 1500) loss: 1.0169 time per epoch: 0.1s
# (Epoch 259 / 1500) loss: 1.0160 time per epoch: 0.1s
# (Epoch 260 / 1500) loss: 1.0235 time per epoch: 0.1s
# (Epoch 261 / 1500) loss: 1.0091 time per epoch: 0.1s
# (Epoch 262 / 1500) loss: 1.0191 time per epoch: 0.1s
# (Epoch 263 / 1500) loss: 1.0011 time per epoch: 0.1s
# (Epoch 264 / 1500) loss: 1.0066 time per epoch: 0.1s
# (Epoch 265 / 1500) loss: 1.0065 time per epoch: 0.1s
# (Epoch 266 / 1500) loss: 1.0307 time per epoch: 0.1s
# (Epoch 267 / 1500) loss: 0.9954 time per epoch: 0.1s
# (Epoch 268 / 1500) loss: 0.9864 time per epoch: 0.1s
# (Epoch 269 / 1500) loss: 0.9902 time per epoch: 0.1s
# (Epoch 270 / 1500) loss: 1.0036 time per epoch: 0.1s
# (Epoch 271 / 1500) loss: 1.0137 time per epoch: 0.1s
# (Epoch 272 / 1500) loss: 1.0083 time per epoch: 0.1s
# (Epoch 273 / 1500) loss: 0.9919 time per epoch: 0.1s
# (Epoch 274 / 1500) loss: 0.9890 time per epoch: 0.1s
# (Epoch 275 / 1500) loss: 0.9759 time per epoch: 0.1s
# (Epoch 276 / 1500) loss: 0.9990 time per epoch: 0.1s
# (Epoch 277 / 1500) loss: 0.9953 time per epoch: 0.1s
# (Epoch 278 / 1500) loss: 1.0116 time per epoch: 0.1s
# (Epoch 279 / 1500) loss: 0.9865 time per epoch: 0.1s
# (Epoch 280 / 1500) loss: 1.0017 time per epoch: 0.1s
# (Epoch 281 / 1500) loss: 1.0006 time per epoch: 0.1s
# (Epoch 282 / 1500) loss: 1.0076 time per epoch: 0.1s
# (Epoch 283 / 1500) loss: 1.0070 time per epoch: 0.1s
# (Epoch 284 / 1500) loss: 0.9990 time per epoch: 0.1s
# (Epoch 285 / 1500) loss: 0.9702 time per epoch: 0.1s
# (Epoch 286 / 1500) loss: 0.9991 time per epoch: 0.1s
# (Epoch 287 / 1500) loss: 0.9761 time per epoch: 0.1s
# (Epoch 288 / 1500) loss: 0.9782 time per epoch: 0.1s
# (Epoch 289 / 1500) loss: 0.9838 time per epoch: 0.1s
# (Epoch 290 / 1500) loss: 0.9936 time per epoch: 0.1s
# (Epoch 291 / 1500) loss: 0.9745 time per epoch: 0.1s
# (Epoch 292 / 1500) loss: 1.0002 time per epoch: 0.1s
# (Epoch 293 / 1500) loss: 0.9754 time per epoch: 0.1s
# (Epoch 294 / 1500) loss: 0.9781 time per epoch: 0.1s
# (Epoch 295 / 1500) loss: 0.9812 time per epoch: 0.1s
# (Epoch 296 / 1500) loss: 0.9685 time per epoch: 0.1s
# (Epoch 297 / 1500) loss: 0.9873 time per epoch: 0.1s
# (Epoch 298 / 1500) loss: 0.9799 time per epoch: 0.1s
# (Epoch 299 / 1500) loss: 0.9850 time per epoch: 0.1s
# (Epoch 300 / 1500) loss: 0.9807 time per epoch: 0.1s
# (Epoch 301 / 1500) loss: 0.9706 time per epoch: 0.1s
# (Epoch 302 / 1500) loss: 0.9745 time per epoch: 0.1s
# (Epoch 303 / 1500) loss: 0.9847 time per epoch: 0.1s
# (Epoch 304 / 1500) loss: 0.9475 time per epoch: 0.1s
# (Epoch 305 / 1500) loss: 0.9628 time per epoch: 0.1s
# (Epoch 306 / 1500) loss: 0.9667 time per epoch: 0.1s
# (Epoch 307 / 1500) loss: 0.9718 time per epoch: 0.1s
# (Epoch 308 / 1500) loss: 0.9741 time per epoch: 0.1s
# (Epoch 309 / 1500) loss: 0.9632 time per epoch: 0.1s
# (Epoch 310 / 1500) loss: 0.9612 time per epoch: 0.1s
# (Epoch 311 / 1500) loss: 0.9840 time per epoch: 0.1s
# (Epoch 312 / 1500) loss: 0.9752 time per epoch: 0.1s
# (Epoch 313 / 1500) loss: 0.9647 time per epoch: 0.1s
# (Epoch 314 / 1500) loss: 0.9383 time per epoch: 0.1s
# (Epoch 315 / 1500) loss: 0.9704 time per epoch: 0.1s
# (Epoch 316 / 1500) loss: 0.9523 time per epoch: 0.1s
# (Epoch 317 / 1500) loss: 0.9556 time per epoch: 0.1s
# (Epoch 318 / 1500) loss: 0.9681 time per epoch: 0.1s
# (Epoch 319 / 1500) loss: 0.9579 time per epoch: 0.1s
# (Epoch 320 / 1500) loss: 0.9460 time per epoch: 0.1s
# (Epoch 321 / 1500) loss: 0.9465 time per epoch: 0.1s
# (Epoch 322 / 1500) loss: 0.9458 time per epoch: 0.1s
# (Epoch 323 / 1500) loss: 0.9437 time per epoch: 0.1s
# (Epoch 324 / 1500) loss: 0.9760 time per epoch: 0.1s
# (Epoch 325 / 1500) loss: 0.9796 time per epoch: 0.1s
# (Epoch 326 / 1500) loss: 0.9723 time per epoch: 0.1s
# (Epoch 327 / 1500) loss: 0.9487 time per epoch: 0.1s
# (Epoch 328 / 1500) loss: 0.9651 time per epoch: 0.1s
# (Epoch 329 / 1500) loss: 0.9660 time per epoch: 0.1s
# (Epoch 330 / 1500) loss: 0.9454 time per epoch: 0.1s
# (Epoch 331 / 1500) loss: 0.9324 time per epoch: 0.1s
# (Epoch 332 / 1500) loss: 0.9419 time per epoch: 0.1s
# (Epoch 333 / 1500) loss: 0.9294 time per epoch: 0.1s
# (Epoch 334 / 1500) loss: 0.9663 time per epoch: 0.1s
# (Epoch 335 / 1500) loss: 0.9412 time per epoch: 0.1s
# (Epoch 336 / 1500) loss: 0.9352 time per epoch: 0.1s
# (Epoch 337 / 1500) loss: 0.9629 time per epoch: 0.1s
# (Epoch 338 / 1500) loss: 0.9225 time per epoch: 0.1s
# (Epoch 339 / 1500) loss: 0.9357 time per epoch: 0.1s
# (Epoch 340 / 1500) loss: 0.9336 time per epoch: 0.1s
# (Epoch 341 / 1500) loss: 0.9503 time per epoch: 0.1s
# (Epoch 342 / 1500) loss: 0.9523 time per epoch: 0.1s
# (Epoch 343 / 1500) loss: 0.9293 time per epoch: 0.1s
# (Epoch 344 / 1500) loss: 0.9398 time per epoch: 0.1s
# (Epoch 345 / 1500) loss: 0.9469 time per epoch: 0.1s
# (Epoch 346 / 1500) loss: 0.9511 time per epoch: 0.1s
# (Epoch 347 / 1500) loss: 0.9103 time per epoch: 0.1s
# (Epoch 348 / 1500) loss: 0.9469 time per epoch: 0.1s
# (Epoch 349 / 1500) loss: 0.9429 time per epoch: 0.1s
# (Epoch 350 / 1500) loss: 0.9389 time per epoch: 0.1s
# (Epoch 351 / 1500) loss: 0.9574 time per epoch: 0.1s
# (Epoch 352 / 1500) loss: 0.9461 time per epoch: 0.1s
# (Epoch 353 / 1500) loss: 0.9480 time per epoch: 0.1s
# (Epoch 354 / 1500) loss: 0.9555 time per epoch: 0.1s
# (Epoch 355 / 1500) loss: 0.9234 time per epoch: 0.1s
# (Epoch 356 / 1500) loss: 0.9294 time per epoch: 0.1s
# (Epoch 357 / 1500) loss: 0.9482 time per epoch: 0.1s
# (Epoch 358 / 1500) loss: 0.9408 time per epoch: 0.1s
# (Epoch 359 / 1500) loss: 0.9113 time per epoch: 0.1s
# (Epoch 360 / 1500) loss: 0.9317 time per epoch: 0.1s
# (Epoch 361 / 1500) loss: 0.9404 time per epoch: 0.1s
# (Epoch 362 / 1500) loss: 0.9200 time per epoch: 0.1s
# (Epoch 363 / 1500) loss: 0.9319 time per epoch: 0.1s
# (Epoch 364 / 1500) loss: 0.9401 time per epoch: 0.1s
# (Epoch 365 / 1500) loss: 0.9421 time per epoch: 0.1s
# (Epoch 366 / 1500) loss: 0.9291 time per epoch: 0.1s
# (Epoch 367 / 1500) loss: 0.9436 time per epoch: 0.1s
# (Epoch 368 / 1500) loss: 0.9280 time per epoch: 0.1s
# (Epoch 369 / 1500) loss: 0.9230 time per epoch: 0.1s
# (Epoch 370 / 1500) loss: 0.9210 time per epoch: 0.1s
# (Epoch 371 / 1500) loss: 0.9322 time per epoch: 0.1s
# (Epoch 372 / 1500) loss: 0.9205 time per epoch: 0.1s
# (Epoch 373 / 1500) loss: 0.9165 time per epoch: 0.1s
# (Epoch 374 / 1500) loss: 0.9342 time per epoch: 0.1s
# (Epoch 375 / 1500) loss: 0.9356 time per epoch: 0.1s
# (Epoch 376 / 1500) loss: 0.9503 time per epoch: 0.1s
# (Epoch 377 / 1500) loss: 0.9329 time per epoch: 0.1s
# (Epoch 378 / 1500) loss: 0.9285 time per epoch: 0.1s
# (Epoch 379 / 1500) loss: 0.9311 time per epoch: 0.1s
# (Epoch 380 / 1500) loss: 0.9220 time per epoch: 0.1s
# (Epoch 381 / 1500) loss: 0.9265 time per epoch: 0.1s
# (Epoch 382 / 1500) loss: 0.9166 time per epoch: 0.1s
# (Epoch 383 / 1500) loss: 0.9204 time per epoch: 0.1s
# (Epoch 384 / 1500) loss: 0.9097 time per epoch: 0.1s
# (Epoch 385 / 1500) loss: 0.8979 time per epoch: 0.1s
# (Epoch 386 / 1500) loss: 0.9184 time per epoch: 0.1s
# (Epoch 387 / 1500) loss: 0.9226 time per epoch: 0.1s
# (Epoch 388 / 1500) loss: 0.9096 time per epoch: 0.1s
# (Epoch 389 / 1500) loss: 0.9217 time per epoch: 0.1s
# (Epoch 390 / 1500) loss: 0.9171 time per epoch: 0.1s
# (Epoch 391 / 1500) loss: 0.8878 time per epoch: 0.1s
# (Epoch 392 / 1500) loss: 0.9145 time per epoch: 0.1s
# (Epoch 393 / 1500) loss: 0.9042 time per epoch: 0.1s
# (Epoch 394 / 1500) loss: 0.9137 time per epoch: 0.1s
# (Epoch 395 / 1500) loss: 0.9148 time per epoch: 0.1s
# (Epoch 396 / 1500) loss: 0.8979 time per epoch: 0.1s
# (Epoch 397 / 1500) loss: 0.8959 time per epoch: 0.1s
# (Epoch 398 / 1500) loss: 0.9058 time per epoch: 0.1s
# (Epoch 399 / 1500) loss: 0.9121 time per epoch: 0.1s
# (Epoch 400 / 1500) loss: 0.8941 time per epoch: 0.1s
# (Epoch 401 / 1500) loss: 0.9226 time per epoch: 0.1s
# (Epoch 402 / 1500) loss: 0.8998 time per epoch: 0.1s
# (Epoch 403 / 1500) loss: 0.8779 time per epoch: 0.1s
# (Epoch 404 / 1500) loss: 0.9139 time per epoch: 0.1s
# (Epoch 405 / 1500) loss: 0.9184 time per epoch: 0.1s
# (Epoch 406 / 1500) loss: 0.8856 time per epoch: 0.1s
# (Epoch 407 / 1500) loss: 0.9059 time per epoch: 0.1s
# (Epoch 408 / 1500) loss: 0.9125 time per epoch: 0.1s
# (Epoch 409 / 1500) loss: 0.8922 time per epoch: 0.1s
# (Epoch 410 / 1500) loss: 0.8902 time per epoch: 0.1s
# (Epoch 411 / 1500) loss: 0.9067 time per epoch: 0.1s
# (Epoch 412 / 1500) loss: 0.9089 time per epoch: 0.1s
# (Epoch 413 / 1500) loss: 0.9174 time per epoch: 0.1s
# (Epoch 414 / 1500) loss: 0.9054 time per epoch: 0.1s
# (Epoch 415 / 1500) loss: 0.8859 time per epoch: 0.1s
# (Epoch 416 / 1500) loss: 0.8943 time per epoch: 0.1s
# (Epoch 417 / 1500) loss: 0.8914 time per epoch: 0.1s
# (Epoch 418 / 1500) loss: 0.8980 time per epoch: 0.1s
# (Epoch 419 / 1500) loss: 0.9044 time per epoch: 0.1s
# (Epoch 420 / 1500) loss: 0.9059 time per epoch: 0.1s
# (Epoch 421 / 1500) loss: 0.9046 time per epoch: 0.1s
# (Epoch 422 / 1500) loss: 0.9004 time per epoch: 0.1s
# (Epoch 423 / 1500) loss: 0.8805 time per epoch: 0.1s
# (Epoch 424 / 1500) loss: 0.8876 time per epoch: 0.1s
# (Epoch 425 / 1500) loss: 0.8812 time per epoch: 0.1s
# (Epoch 426 / 1500) loss: 0.8876 time per epoch: 0.1s
# (Epoch 427 / 1500) loss: 0.8844 time per epoch: 0.1s
# (Epoch 428 / 1500) loss: 0.9012 time per epoch: 0.1s
# (Epoch 429 / 1500) loss: 0.9084 time per epoch: 0.1s
# (Epoch 430 / 1500) loss: 0.9040 time per epoch: 0.1s
# (Epoch 431 / 1500) loss: 0.9083 time per epoch: 0.1s
# (Epoch 432 / 1500) loss: 0.8997 time per epoch: 0.1s
# (Epoch 433 / 1500) loss: 0.9248 time per epoch: 0.1s
# (Epoch 434 / 1500) loss: 0.9146 time per epoch: 0.1s
# (Epoch 435 / 1500) loss: 0.9077 time per epoch: 0.1s
# (Epoch 436 / 1500) loss: 0.8981 time per epoch: 0.1s
# (Epoch 437 / 1500) loss: 0.8927 time per epoch: 0.1s
# (Epoch 438 / 1500) loss: 0.8891 time per epoch: 0.1s
# (Epoch 439 / 1500) loss: 0.9115 time per epoch: 0.1s
# (Epoch 440 / 1500) loss: 0.8869 time per epoch: 0.1s
# (Epoch 441 / 1500) loss: 0.8991 time per epoch: 0.1s
# (Epoch 442 / 1500) loss: 0.8828 time per epoch: 0.1s
# (Epoch 443 / 1500) loss: 0.8878 time per epoch: 0.1s
# (Epoch 444 / 1500) loss: 0.8851 time per epoch: 0.1s
# (Epoch 445 / 1500) loss: 0.8745 time per epoch: 0.1s
# (Epoch 446 / 1500) loss: 0.8834 time per epoch: 0.1s
# (Epoch 447 / 1500) loss: 0.8719 time per epoch: 0.1s
# (Epoch 448 / 1500) loss: 0.8937 time per epoch: 0.1s
# (Epoch 449 / 1500) loss: 0.8791 time per epoch: 0.1s
# (Epoch 450 / 1500) loss: 0.8850 time per epoch: 0.1s
# (Epoch 451 / 1500) loss: 0.8716 time per epoch: 0.1s
# (Epoch 452 / 1500) loss: 0.8647 time per epoch: 0.1s
# (Epoch 453 / 1500) loss: 0.8612 time per epoch: 0.1s
# (Epoch 454 / 1500) loss: 0.8761 time per epoch: 0.1s
# (Epoch 455 / 1500) loss: 0.8866 time per epoch: 0.1s
# (Epoch 456 / 1500) loss: 0.9032 time per epoch: 0.1s
# (Epoch 457 / 1500) loss: 0.8613 time per epoch: 0.1s
# (Epoch 458 / 1500) loss: 0.9036 time per epoch: 0.1s
# (Epoch 459 / 1500) loss: 0.8683 time per epoch: 0.1s
# (Epoch 460 / 1500) loss: 0.8808 time per epoch: 0.1s
# (Epoch 461 / 1500) loss: 0.9019 time per epoch: 0.1s
# (Epoch 462 / 1500) loss: 0.9005 time per epoch: 0.1s
# (Epoch 463 / 1500) loss: 0.8855 time per epoch: 0.1s
# (Epoch 464 / 1500) loss: 0.8819 time per epoch: 0.1s
# (Epoch 465 / 1500) loss: 0.8475 time per epoch: 0.1s
# (Epoch 466 / 1500) loss: 0.8616 time per epoch: 0.1s
# (Epoch 467 / 1500) loss: 0.9034 time per epoch: 0.1s
# (Epoch 468 / 1500) loss: 0.8801 time per epoch: 0.1s
# (Epoch 469 / 1500) loss: 0.8919 time per epoch: 0.1s
# (Epoch 470 / 1500) loss: 0.8811 time per epoch: 0.1s
# (Epoch 471 / 1500) loss: 0.8791 time per epoch: 0.1s
# (Epoch 472 / 1500) loss: 0.8679 time per epoch: 0.1s
# (Epoch 473 / 1500) loss: 0.8683 time per epoch: 0.1s
# (Epoch 474 / 1500) loss: 0.8650 time per epoch: 0.1s
# (Epoch 475 / 1500) loss: 0.8805 time per epoch: 0.1s
# (Epoch 476 / 1500) loss: 0.8856 time per epoch: 0.1s
# (Epoch 477 / 1500) loss: 0.8705 time per epoch: 0.1s
# (Epoch 478 / 1500) loss: 0.8399 time per epoch: 0.1s
# (Epoch 479 / 1500) loss: 0.8674 time per epoch: 0.1s
# (Epoch 480 / 1500) loss: 0.8670 time per epoch: 0.1s
# (Epoch 481 / 1500) loss: 0.8845 time per epoch: 0.1s
# (Epoch 482 / 1500) loss: 0.8705 time per epoch: 0.1s
# (Epoch 483 / 1500) loss: 0.8850 time per epoch: 0.1s
# (Epoch 484 / 1500) loss: 0.8558 time per epoch: 0.1s
# (Epoch 485 / 1500) loss: 0.8662 time per epoch: 0.1s
# (Epoch 486 / 1500) loss: 0.8699 time per epoch: 0.1s
# (Epoch 487 / 1500) loss: 0.8762 time per epoch: 0.1s
# (Epoch 488 / 1500) loss: 0.8755 time per epoch: 0.1s
# (Epoch 489 / 1500) loss: 0.8708 time per epoch: 0.1s
# (Epoch 490 / 1500) loss: 0.8813 time per epoch: 0.1s
# (Epoch 491 / 1500) loss: 0.8678 time per epoch: 0.1s
# (Epoch 492 / 1500) loss: 0.8662 time per epoch: 0.1s
# (Epoch 493 / 1500) loss: 0.8576 time per epoch: 0.1s
# (Epoch 494 / 1500) loss: 0.8611 time per epoch: 0.1s
# (Epoch 495 / 1500) loss: 0.8709 time per epoch: 0.1s
# (Epoch 496 / 1500) loss: 0.8723 time per epoch: 0.1s
# (Epoch 497 / 1500) loss: 0.8774 time per epoch: 0.1s
# (Epoch 498 / 1500) loss: 0.8440 time per epoch: 0.1s
# (Epoch 499 / 1500) loss: 0.8594 time per epoch: 0.1s
# (Epoch 500 / 1500) loss: 0.8460 time per epoch: 0.1s
# (Epoch 501 / 1500) loss: 0.8643 time per epoch: 0.1s
# (Epoch 502 / 1500) loss: 0.8731 time per epoch: 0.1s
# (Epoch 503 / 1500) loss: 0.8686 time per epoch: 0.1s
# (Epoch 504 / 1500) loss: 0.8360 time per epoch: 0.1s
# (Epoch 505 / 1500) loss: 0.8504 time per epoch: 0.1s
# (Epoch 506 / 1500) loss: 0.8453 time per epoch: 0.1s
# (Epoch 507 / 1500) loss: 0.8229 time per epoch: 0.1s
# (Epoch 508 / 1500) loss: 0.8597 time per epoch: 0.1s
# (Epoch 509 / 1500) loss: 0.8690 time per epoch: 0.1s
# (Epoch 510 / 1500) loss: 0.8534 time per epoch: 0.1s
# (Epoch 511 / 1500) loss: 0.8770 time per epoch: 0.1s
# (Epoch 512 / 1500) loss: 0.8493 time per epoch: 0.1s
# (Epoch 513 / 1500) loss: 0.8735 time per epoch: 0.1s
# (Epoch 514 / 1500) loss: 0.8480 time per epoch: 0.1s
# (Epoch 515 / 1500) loss: 0.8588 time per epoch: 0.1s
# (Epoch 516 / 1500) loss: 0.8453 time per epoch: 0.1s
# (Epoch 517 / 1500) loss: 0.8491 time per epoch: 0.1s
# (Epoch 518 / 1500) loss: 0.8495 time per epoch: 0.1s
# (Epoch 519 / 1500) loss: 0.8670 time per epoch: 0.1s
# (Epoch 520 / 1500) loss: 0.8383 time per epoch: 0.1s
# (Epoch 521 / 1500) loss: 0.8715 time per epoch: 0.1s
# (Epoch 522 / 1500) loss: 0.8427 time per epoch: 0.1s
# (Epoch 523 / 1500) loss: 0.8498 time per epoch: 0.1s
# (Epoch 524 / 1500) loss: 0.8608 time per epoch: 0.1s
# (Epoch 525 / 1500) loss: 0.8407 time per epoch: 0.1s
# (Epoch 526 / 1500) loss: 0.8416 time per epoch: 0.1s
# (Epoch 527 / 1500) loss: 0.8133 time per epoch: 0.1s
# (Epoch 528 / 1500) loss: 0.8302 time per epoch: 0.1s
# (Epoch 529 / 1500) loss: 0.8633 time per epoch: 0.1s
# (Epoch 530 / 1500) loss: 0.8613 time per epoch: 0.1s
# (Epoch 531 / 1500) loss: 0.8381 time per epoch: 0.1s
# (Epoch 532 / 1500) loss: 0.8423 time per epoch: 0.1s
# (Epoch 533 / 1500) loss: 0.8384 time per epoch: 0.1s
# (Epoch 534 / 1500) loss: 0.8533 time per epoch: 0.1s
# (Epoch 535 / 1500) loss: 0.8264 time per epoch: 0.1s
# (Epoch 536 / 1500) loss: 0.8355 time per epoch: 0.1s
# (Epoch 537 / 1500) loss: 0.8591 time per epoch: 0.1s
# (Epoch 538 / 1500) loss: 0.8197 time per epoch: 0.1s
# (Epoch 539 / 1500) loss: 0.8526 time per epoch: 0.1s
# (Epoch 540 / 1500) loss: 0.8299 time per epoch: 0.1s
# (Epoch 541 / 1500) loss: 0.8245 time per epoch: 0.1s
# (Epoch 542 / 1500) loss: 0.8454 time per epoch: 0.1s
# (Epoch 543 / 1500) loss: 0.8380 time per epoch: 0.1s
# (Epoch 544 / 1500) loss: 0.8164 time per epoch: 0.1s
# (Epoch 545 / 1500) loss: 0.8453 time per epoch: 0.1s
# (Epoch 546 / 1500) loss: 0.8330 time per epoch: 0.1s
# (Epoch 547 / 1500) loss: 0.8352 time per epoch: 0.1s
# (Epoch 548 / 1500) loss: 0.8341 time per epoch: 0.1s
# (Epoch 549 / 1500) loss: 0.8296 time per epoch: 0.1s
# (Epoch 550 / 1500) loss: 0.8400 time per epoch: 0.1s
# (Epoch 551 / 1500) loss: 0.8089 time per epoch: 0.1s
# (Epoch 552 / 1500) loss: 0.8298 time per epoch: 0.1s
# (Epoch 553 / 1500) loss: 0.8396 time per epoch: 0.1s
# (Epoch 554 / 1500) loss: 0.8283 time per epoch: 0.1s
# (Epoch 555 / 1500) loss: 0.8234 time per epoch: 0.1s
# (Epoch 556 / 1500) loss: 0.8341 time per epoch: 0.1s
# (Epoch 557 / 1500) loss: 0.8028 time per epoch: 0.1s
# (Epoch 558 / 1500) loss: 0.8271 time per epoch: 0.1s
# (Epoch 559 / 1500) loss: 0.8376 time per epoch: 0.1s
# (Epoch 560 / 1500) loss: 0.8295 time per epoch: 0.1s
# (Epoch 561 / 1500) loss: 0.8279 time per epoch: 0.1s
# (Epoch 562 / 1500) loss: 0.8272 time per epoch: 0.1s
# (Epoch 563 / 1500) loss: 0.8370 time per epoch: 0.1s
# (Epoch 564 / 1500) loss: 0.8121 time per epoch: 0.1s
# (Epoch 565 / 1500) loss: 0.8239 time per epoch: 0.1s
# (Epoch 566 / 1500) loss: 0.8163 time per epoch: 0.1s
# (Epoch 567 / 1500) loss: 0.8043 time per epoch: 0.1s
# (Epoch 568 / 1500) loss: 0.8508 time per epoch: 0.1s
# (Epoch 569 / 1500) loss: 0.8107 time per epoch: 0.1s
# (Epoch 570 / 1500) loss: 0.8186 time per epoch: 0.1s
# (Epoch 571 / 1500) loss: 0.8180 time per epoch: 0.1s
# (Epoch 572 / 1500) loss: 0.8306 time per epoch: 0.1s
# (Epoch 573 / 1500) loss: 0.8163 time per epoch: 0.1s
# (Epoch 574 / 1500) loss: 0.8071 time per epoch: 0.1s
# (Epoch 575 / 1500) loss: 0.8090 time per epoch: 0.1s
# (Epoch 576 / 1500) loss: 0.8053 time per epoch: 0.1s
# (Epoch 577 / 1500) loss: 0.8247 time per epoch: 0.1s
# (Epoch 578 / 1500) loss: 0.8058 time per epoch: 0.1s
# (Epoch 579 / 1500) loss: 0.8284 time per epoch: 0.1s
# (Epoch 580 / 1500) loss: 0.8157 time per epoch: 0.1s
# (Epoch 581 / 1500) loss: 0.7947 time per epoch: 0.1s
# (Epoch 582 / 1500) loss: 0.8070 time per epoch: 0.1s
# (Epoch 583 / 1500) loss: 0.8118 time per epoch: 0.1s
# (Epoch 584 / 1500) loss: 0.8061 time per epoch: 0.1s
# (Epoch 585 / 1500) loss: 0.8302 time per epoch: 0.1s
# (Epoch 586 / 1500) loss: 0.8197 time per epoch: 0.1s
# (Epoch 587 / 1500) loss: 0.8041 time per epoch: 0.1s
# (Epoch 588 / 1500) loss: 0.7815 time per epoch: 0.1s
# (Epoch 589 / 1500) loss: 0.7934 time per epoch: 0.1s
# (Epoch 590 / 1500) loss: 0.8012 time per epoch: 0.1s
# (Epoch 591 / 1500) loss: 0.8013 time per epoch: 0.1s
# (Epoch 592 / 1500) loss: 0.8194 time per epoch: 0.1s
# (Epoch 593 / 1500) loss: 0.8024 time per epoch: 0.1s
# (Epoch 594 / 1500) loss: 0.8153 time per epoch: 0.1s
# (Epoch 595 / 1500) loss: 0.8211 time per epoch: 0.1s
# (Epoch 596 / 1500) loss: 0.7908 time per epoch: 0.1s
# (Epoch 597 / 1500) loss: 0.7862 time per epoch: 0.1s
# (Epoch 598 / 1500) loss: 0.8058 time per epoch: 0.1s
# (Epoch 599 / 1500) loss: 0.7845 time per epoch: 0.1s
# (Epoch 600 / 1500) loss: 0.8085 time per epoch: 0.1s
# (Epoch 601 / 1500) loss: 0.8251 time per epoch: 0.1s
# (Epoch 602 / 1500) loss: 0.8093 time per epoch: 0.1s
# (Epoch 603 / 1500) loss: 0.8073 time per epoch: 0.1s
# (Epoch 604 / 1500) loss: 0.8196 time per epoch: 0.1s
# (Epoch 605 / 1500) loss: 0.8142 time per epoch: 0.1s
# (Epoch 606 / 1500) loss: 0.8003 time per epoch: 0.1s
# (Epoch 607 / 1500) loss: 0.7733 time per epoch: 0.1s
# (Epoch 608 / 1500) loss: 0.8064 time per epoch: 0.1s
# (Epoch 609 / 1500) loss: 0.7838 time per epoch: 0.1s
# (Epoch 610 / 1500) loss: 0.8128 time per epoch: 0.1s
# (Epoch 611 / 1500) loss: 0.7967 time per epoch: 0.1s
# (Epoch 612 / 1500) loss: 0.7972 time per epoch: 0.1s
# (Epoch 613 / 1500) loss: 0.8060 time per epoch: 0.1s
# (Epoch 614 / 1500) loss: 0.8064 time per epoch: 0.1s
# (Epoch 615 / 1500) loss: 0.8034 time per epoch: 0.1s
# (Epoch 616 / 1500) loss: 0.7913 time per epoch: 0.1s
# (Epoch 617 / 1500) loss: 0.7859 time per epoch: 0.1s
# (Epoch 618 / 1500) loss: 0.7980 time per epoch: 0.1s
# (Epoch 619 / 1500) loss: 0.7881 time per epoch: 0.1s
# (Epoch 620 / 1500) loss: 0.8086 time per epoch: 0.1s
# (Epoch 621 / 1500) loss: 0.7739 time per epoch: 0.1s
# (Epoch 622 / 1500) loss: 0.8127 time per epoch: 0.1s
# (Epoch 623 / 1500) loss: 0.7900 time per epoch: 0.1s
# (Epoch 624 / 1500) loss: 0.7990 time per epoch: 0.1s
# (Epoch 625 / 1500) loss: 0.8216 time per epoch: 0.1s
# (Epoch 626 / 1500) loss: 0.7611 time per epoch: 0.1s
# (Epoch 627 / 1500) loss: 0.7720 time per epoch: 0.1s
# (Epoch 628 / 1500) loss: 0.7654 time per epoch: 0.1s
# (Epoch 629 / 1500) loss: 0.7874 time per epoch: 0.1s
# (Epoch 630 / 1500) loss: 0.7610 time per epoch: 0.1s
# (Epoch 631 / 1500) loss: 0.7943 time per epoch: 0.1s
# (Epoch 632 / 1500) loss: 0.7845 time per epoch: 0.1s
# (Epoch 633 / 1500) loss: 0.7752 time per epoch: 0.1s
# (Epoch 634 / 1500) loss: 0.7759 time per epoch: 0.1s
# (Epoch 635 / 1500) loss: 0.8032 time per epoch: 0.1s
# (Epoch 636 / 1500) loss: 0.7839 time per epoch: 0.1s
# (Epoch 637 / 1500) loss: 0.7728 time per epoch: 0.1s
# (Epoch 638 / 1500) loss: 0.8011 time per epoch: 0.1s
# (Epoch 639 / 1500) loss: 0.7635 time per epoch: 0.1s
# (Epoch 640 / 1500) loss: 0.7888 time per epoch: 0.1s
# (Epoch 641 / 1500) loss: 0.7719 time per epoch: 0.1s
# (Epoch 642 / 1500) loss: 0.7749 time per epoch: 0.1s
# (Epoch 643 / 1500) loss: 0.7471 time per epoch: 0.1s
# (Epoch 644 / 1500) loss: 0.7375 time per epoch: 0.1s
# (Epoch 645 / 1500) loss: 0.7829 time per epoch: 0.1s
# (Epoch 646 / 1500) loss: 0.7486 time per epoch: 0.1s
# (Epoch 647 / 1500) loss: 0.7842 time per epoch: 0.1s
# (Epoch 648 / 1500) loss: 0.7789 time per epoch: 0.1s
# (Epoch 649 / 1500) loss: 0.7914 time per epoch: 0.1s
# (Epoch 650 / 1500) loss: 0.7524 time per epoch: 0.1s
# (Epoch 651 / 1500) loss: 0.7514 time per epoch: 0.1s
# (Epoch 652 / 1500) loss: 0.7732 time per epoch: 0.1s
# (Epoch 653 / 1500) loss: 0.7778 time per epoch: 0.1s
# (Epoch 654 / 1500) loss: 0.7724 time per epoch: 0.1s
# (Epoch 655 / 1500) loss: 0.7554 time per epoch: 0.1s
# (Epoch 656 / 1500) loss: 0.7488 time per epoch: 0.1s
# (Epoch 657 / 1500) loss: 0.7452 time per epoch: 0.1s
# (Epoch 658 / 1500) loss: 0.7680 time per epoch: 0.1s
# (Epoch 659 / 1500) loss: 0.7744 time per epoch: 0.1s
# (Epoch 660 / 1500) loss: 0.7515 time per epoch: 0.1s
# (Epoch 661 / 1500) loss: 0.7596 time per epoch: 0.1s
# (Epoch 662 / 1500) loss: 0.7598 time per epoch: 0.1s
# (Epoch 663 / 1500) loss: 0.7919 time per epoch: 0.1s
# (Epoch 664 / 1500) loss: 0.7803 time per epoch: 0.1s
# (Epoch 665 / 1500) loss: 0.7346 time per epoch: 0.1s
# (Epoch 666 / 1500) loss: 0.7384 time per epoch: 0.1s
# (Epoch 667 / 1500) loss: 0.7659 time per epoch: 0.1s
# (Epoch 668 / 1500) loss: 0.7638 time per epoch: 0.1s
# (Epoch 669 / 1500) loss: 0.7654 time per epoch: 0.1s
# (Epoch 670 / 1500) loss: 0.7460 time per epoch: 0.1s
# (Epoch 671 / 1500) loss: 0.7809 time per epoch: 0.1s
# (Epoch 672 / 1500) loss: 0.7448 time per epoch: 0.1s
# (Epoch 673 / 1500) loss: 0.7566 time per epoch: 0.1s
# (Epoch 674 / 1500) loss: 0.7461 time per epoch: 0.1s
# (Epoch 675 / 1500) loss: 0.7728 time per epoch: 0.1s
# (Epoch 676 / 1500) loss: 0.7549 time per epoch: 0.1s
# (Epoch 677 / 1500) loss: 0.7231 time per epoch: 0.1s
# (Epoch 678 / 1500) loss: 0.7793 time per epoch: 0.1s
# (Epoch 679 / 1500) loss: 0.7575 time per epoch: 0.1s
# (Epoch 680 / 1500) loss: 0.7792 time per epoch: 0.1s
# (Epoch 681 / 1500) loss: 0.7708 time per epoch: 0.1s
# (Epoch 682 / 1500) loss: 0.7505 time per epoch: 0.1s
# (Epoch 683 / 1500) loss: 0.7581 time per epoch: 0.1s
# (Epoch 684 / 1500) loss: 0.7462 time per epoch: 0.1s
# (Epoch 685 / 1500) loss: 0.7241 time per epoch: 0.1s
# (Epoch 686 / 1500) loss: 0.7465 time per epoch: 0.1s
# (Epoch 687 / 1500) loss: 0.7287 time per epoch: 0.1s
# (Epoch 688 / 1500) loss: 0.7795 time per epoch: 0.1s
# (Epoch 689 / 1500) loss: 0.7649 time per epoch: 0.1s
# (Epoch 690 / 1500) loss: 0.7499 time per epoch: 0.1s
# (Epoch 691 / 1500) loss: 0.7436 time per epoch: 0.1s
# (Epoch 692 / 1500) loss: 0.7483 time per epoch: 0.1s
# (Epoch 693 / 1500) loss: 0.7374 time per epoch: 0.1s
# (Epoch 694 / 1500) loss: 0.7569 time per epoch: 0.1s
# (Epoch 695 / 1500) loss: 0.7413 time per epoch: 0.1s
# (Epoch 696 / 1500) loss: 0.7446 time per epoch: 0.1s
# (Epoch 697 / 1500) loss: 0.7380 time per epoch: 0.1s
# (Epoch 698 / 1500) loss: 0.7568 time per epoch: 0.1s
# (Epoch 699 / 1500) loss: 0.7593 time per epoch: 0.1s
# (Epoch 700 / 1500) loss: 0.7282 time per epoch: 0.1s
# (Epoch 701 / 1500) loss: 0.7481 time per epoch: 0.1s
# (Epoch 702 / 1500) loss: 0.7416 time per epoch: 0.1s
# (Epoch 703 / 1500) loss: 0.7421 time per epoch: 0.1s
# (Epoch 704 / 1500) loss: 0.7115 time per epoch: 0.1s
# (Epoch 705 / 1500) loss: 0.7274 time per epoch: 0.1s
# (Epoch 706 / 1500) loss: 0.7405 time per epoch: 0.1s
# (Epoch 707 / 1500) loss: 0.7222 time per epoch: 0.1s
# (Epoch 708 / 1500) loss: 0.7140 time per epoch: 0.1s
# (Epoch 709 / 1500) loss: 0.7341 time per epoch: 0.1s
# (Epoch 710 / 1500) loss: 0.7429 time per epoch: 0.1s
# (Epoch 711 / 1500) loss: 0.7345 time per epoch: 0.1s
# (Epoch 712 / 1500) loss: 0.7058 time per epoch: 0.1s
# (Epoch 713 / 1500) loss: 0.7292 time per epoch: 0.1s
# (Epoch 714 / 1500) loss: 0.7514 time per epoch: 0.1s
# (Epoch 715 / 1500) loss: 0.7390 time per epoch: 0.1s
# (Epoch 716 / 1500) loss: 0.7545 time per epoch: 0.1s
# (Epoch 717 / 1500) loss: 0.7328 time per epoch: 0.1s
# (Epoch 718 / 1500) loss: 0.7293 time per epoch: 0.1s
# (Epoch 719 / 1500) loss: 0.7254 time per epoch: 0.1s
# (Epoch 720 / 1500) loss: 0.7165 time per epoch: 0.1s
# (Epoch 721 / 1500) loss: 0.7196 time per epoch: 0.1s
# (Epoch 722 / 1500) loss: 0.7070 time per epoch: 0.1s
# (Epoch 723 / 1500) loss: 0.7076 time per epoch: 0.1s
# (Epoch 724 / 1500) loss: 0.7206 time per epoch: 0.1s
# (Epoch 725 / 1500) loss: 0.7302 time per epoch: 0.1s
# (Epoch 726 / 1500) loss: 0.7346 time per epoch: 0.1s
# (Epoch 727 / 1500) loss: 0.7144 time per epoch: 0.1s
# (Epoch 728 / 1500) loss: 0.7445 time per epoch: 0.1s
# (Epoch 729 / 1500) loss: 0.7111 time per epoch: 0.1s
# (Epoch 730 / 1500) loss: 0.7433 time per epoch: 0.1s
# (Epoch 731 / 1500) loss: 0.7212 time per epoch: 0.1s
# (Epoch 732 / 1500) loss: 0.7319 time per epoch: 0.1s
# (Epoch 733 / 1500) loss: 0.7126 time per epoch: 0.1s
# (Epoch 734 / 1500) loss: 0.7118 time per epoch: 0.1s
# (Epoch 735 / 1500) loss: 0.6993 time per epoch: 0.1s
# (Epoch 736 / 1500) loss: 0.7210 time per epoch: 0.1s
# (Epoch 737 / 1500) loss: 0.7123 time per epoch: 0.1s
# (Epoch 738 / 1500) loss: 0.7271 time per epoch: 0.1s
# (Epoch 739 / 1500) loss: 0.7148 time per epoch: 0.1s
# (Epoch 740 / 1500) loss: 0.6981 time per epoch: 0.1s
# (Epoch 741 / 1500) loss: 0.7223 time per epoch: 0.1s
# (Epoch 742 / 1500) loss: 0.7115 time per epoch: 0.1s
# (Epoch 743 / 1500) loss: 0.6975 time per epoch: 0.1s
# (Epoch 744 / 1500) loss: 0.7083 time per epoch: 0.1s
# (Epoch 745 / 1500) loss: 0.7252 time per epoch: 0.1s
# (Epoch 746 / 1500) loss: 0.7130 time per epoch: 0.1s
# (Epoch 747 / 1500) loss: 0.7016 time per epoch: 0.1s
# (Epoch 748 / 1500) loss: 0.6876 time per epoch: 0.1s
# (Epoch 749 / 1500) loss: 0.6898 time per epoch: 0.1s
# (Epoch 750 / 1500) loss: 0.6851 time per epoch: 0.1s
# (Epoch 751 / 1500) loss: 0.7063 time per epoch: 0.1s
# (Epoch 752 / 1500) loss: 0.6889 time per epoch: 0.1s
# (Epoch 753 / 1500) loss: 0.7305 time per epoch: 0.1s
# (Epoch 754 / 1500) loss: 0.7488 time per epoch: 0.1s
# (Epoch 755 / 1500) loss: 0.7223 time per epoch: 0.1s
# (Epoch 756 / 1500) loss: 0.7240 time per epoch: 0.1s
# (Epoch 757 / 1500) loss: 0.7361 time per epoch: 0.1s
# (Epoch 758 / 1500) loss: 0.7141 time per epoch: 0.1s
# (Epoch 759 / 1500) loss: 0.6939 time per epoch: 0.1s
# (Epoch 760 / 1500) loss: 0.7080 time per epoch: 0.1s
# (Epoch 761 / 1500) loss: 0.6895 time per epoch: 0.1s
# (Epoch 762 / 1500) loss: 0.6982 time per epoch: 0.1s
# (Epoch 763 / 1500) loss: 0.7017 time per epoch: 0.1s
# (Epoch 764 / 1500) loss: 0.6869 time per epoch: 0.1s
# (Epoch 765 / 1500) loss: 0.7197 time per epoch: 0.1s
# (Epoch 766 / 1500) loss: 0.7074 time per epoch: 0.1s
# (Epoch 767 / 1500) loss: 0.6770 time per epoch: 0.1s
# (Epoch 768 / 1500) loss: 0.6859 time per epoch: 0.1s
# (Epoch 769 / 1500) loss: 0.6810 time per epoch: 0.1s
# (Epoch 770 / 1500) loss: 0.6713 time per epoch: 0.1s
# (Epoch 771 / 1500) loss: 0.6972 time per epoch: 0.1s
# (Epoch 772 / 1500) loss: 0.7062 time per epoch: 0.1s
# (Epoch 773 / 1500) loss: 0.7151 time per epoch: 0.1s
# (Epoch 774 / 1500) loss: 0.6893 time per epoch: 0.1s
# (Epoch 775 / 1500) loss: 0.6870 time per epoch: 0.1s
# (Epoch 776 / 1500) loss: 0.6994 time per epoch: 0.1s
# (Epoch 777 / 1500) loss: 0.6662 time per epoch: 0.1s
# (Epoch 778 / 1500) loss: 0.6774 time per epoch: 0.1s
# (Epoch 779 / 1500) loss: 0.7038 time per epoch: 0.1s
# (Epoch 780 / 1500) loss: 0.6663 time per epoch: 0.1s
# (Epoch 781 / 1500) loss: 0.6698 time per epoch: 0.1s
# (Epoch 782 / 1500) loss: 0.6949 time per epoch: 0.1s
# (Epoch 783 / 1500) loss: 0.6863 time per epoch: 0.1s
# (Epoch 784 / 1500) loss: 0.6957 time per epoch: 0.1s
# (Epoch 785 / 1500) loss: 0.6786 time per epoch: 0.1s
# (Epoch 786 / 1500) loss: 0.6892 time per epoch: 0.1s
# (Epoch 787 / 1500) loss: 0.6578 time per epoch: 0.1s
# (Epoch 788 / 1500) loss: 0.6793 time per epoch: 0.1s
# (Epoch 789 / 1500) loss: 0.6717 time per epoch: 0.1s
# (Epoch 790 / 1500) loss: 0.6641 time per epoch: 0.1s
# (Epoch 791 / 1500) loss: 0.6741 time per epoch: 0.1s
# (Epoch 792 / 1500) loss: 0.6640 time per epoch: 0.1s
# (Epoch 793 / 1500) loss: 0.6759 time per epoch: 0.1s
# (Epoch 794 / 1500) loss: 0.6511 time per epoch: 0.1s
# (Epoch 795 / 1500) loss: 0.6844 time per epoch: 0.1s
# (Epoch 796 / 1500) loss: 0.6971 time per epoch: 0.1s
# (Epoch 797 / 1500) loss: 0.6814 time per epoch: 0.1s
# (Epoch 798 / 1500) loss: 0.6831 time per epoch: 0.1s
# (Epoch 799 / 1500) loss: 0.6724 time per epoch: 0.1s
# (Epoch 800 / 1500) loss: 0.6660 time per epoch: 0.1s
# (Epoch 801 / 1500) loss: 0.6813 time per epoch: 0.1s
# (Epoch 802 / 1500) loss: 0.6832 time per epoch: 0.1s
# (Epoch 803 / 1500) loss: 0.6530 time per epoch: 0.1s
# (Epoch 804 / 1500) loss: 0.6940 time per epoch: 0.1s
# (Epoch 805 / 1500) loss: 0.6609 time per epoch: 0.1s
# (Epoch 806 / 1500) loss: 0.6914 time per epoch: 0.1s
# (Epoch 807 / 1500) loss: 0.6537 time per epoch: 0.1s
# (Epoch 808 / 1500) loss: 0.6413 time per epoch: 0.1s
# (Epoch 809 / 1500) loss: 0.6668 time per epoch: 0.1s
# (Epoch 810 / 1500) loss: 0.6815 time per epoch: 0.1s
# (Epoch 811 / 1500) loss: 0.6742 time per epoch: 0.1s
# (Epoch 812 / 1500) loss: 0.6819 time per epoch: 0.1s
# (Epoch 813 / 1500) loss: 0.6646 time per epoch: 0.1s
# (Epoch 814 / 1500) loss: 0.6503 time per epoch: 0.1s
# (Epoch 815 / 1500) loss: 0.6693 time per epoch: 0.1s
# (Epoch 816 / 1500) loss: 0.6585 time per epoch: 0.1s
# (Epoch 817 / 1500) loss: 0.6711 time per epoch: 0.1s
# (Epoch 818 / 1500) loss: 0.6666 time per epoch: 0.1s
# (Epoch 819 / 1500) loss: 0.6269 time per epoch: 0.1s
# (Epoch 820 / 1500) loss: 0.6575 time per epoch: 0.1s
# (Epoch 821 / 1500) loss: 0.6634 time per epoch: 0.1s
# (Epoch 822 / 1500) loss: 0.6553 time per epoch: 0.1s
# (Epoch 823 / 1500) loss: 0.6528 time per epoch: 0.1s
# (Epoch 824 / 1500) loss: 0.6899 time per epoch: 0.1s
# (Epoch 825 / 1500) loss: 0.6443 time per epoch: 0.1s
# (Epoch 826 / 1500) loss: 0.6426 time per epoch: 0.1s
# (Epoch 827 / 1500) loss: 0.6590 time per epoch: 0.1s
# (Epoch 828 / 1500) loss: 0.6488 time per epoch: 0.1s
# (Epoch 829 / 1500) loss: 0.6624 time per epoch: 0.1s
# (Epoch 830 / 1500) loss: 0.6816 time per epoch: 0.1s
# (Epoch 831 / 1500) loss: 0.6718 time per epoch: 0.1s
# (Epoch 832 / 1500) loss: 0.6584 time per epoch: 0.1s
# (Epoch 833 / 1500) loss: 0.6416 time per epoch: 0.1s
# (Epoch 834 / 1500) loss: 0.6640 time per epoch: 0.1s
# (Epoch 835 / 1500) loss: 0.6625 time per epoch: 0.1s
# (Epoch 836 / 1500) loss: 0.6423 time per epoch: 0.1s
# (Epoch 837 / 1500) loss: 0.6552 time per epoch: 0.1s
# (Epoch 838 / 1500) loss: 0.6334 time per epoch: 0.1s
# (Epoch 839 / 1500) loss: 0.6671 time per epoch: 0.1s
# (Epoch 840 / 1500) loss: 0.6278 time per epoch: 0.1s
# (Epoch 841 / 1500) loss: 0.6334 time per epoch: 0.1s
# (Epoch 842 / 1500) loss: 0.6184 time per epoch: 0.1s
# (Epoch 843 / 1500) loss: 0.6582 time per epoch: 0.1s
# (Epoch 844 / 1500) loss: 0.6393 time per epoch: 0.1s
# (Epoch 845 / 1500) loss: 0.6435 time per epoch: 0.1s
# (Epoch 846 / 1500) loss: 0.6194 time per epoch: 0.1s
# (Epoch 847 / 1500) loss: 0.6349 time per epoch: 0.1s
# (Epoch 848 / 1500) loss: 0.6440 time per epoch: 0.1s
# (Epoch 849 / 1500) loss: 0.6154 time per epoch: 0.1s
# (Epoch 850 / 1500) loss: 0.6273 time per epoch: 0.1s
# (Epoch 851 / 1500) loss: 0.6489 time per epoch: 0.1s
# (Epoch 852 / 1500) loss: 0.6233 time per epoch: 0.1s
# (Epoch 853 / 1500) loss: 0.6134 time per epoch: 0.1s
# (Epoch 854 / 1500) loss: 0.6232 time per epoch: 0.1s
# (Epoch 855 / 1500) loss: 0.6147 time per epoch: 0.1s
# (Epoch 856 / 1500) loss: 0.6462 time per epoch: 0.1s
# (Epoch 857 / 1500) loss: 0.6139 time per epoch: 0.1s
# (Epoch 858 / 1500) loss: 0.6282 time per epoch: 0.1s
# (Epoch 859 / 1500) loss: 0.6316 time per epoch: 0.1s
# (Epoch 860 / 1500) loss: 0.6387 time per epoch: 0.1s
# (Epoch 861 / 1500) loss: 0.6323 time per epoch: 0.1s
# (Epoch 862 / 1500) loss: 0.6124 time per epoch: 0.1s
# (Epoch 863 / 1500) loss: 0.6311 time per epoch: 0.1s
# (Epoch 864 / 1500) loss: 0.6276 time per epoch: 0.1s
# (Epoch 865 / 1500) loss: 0.6616 time per epoch: 0.1s
# (Epoch 866 / 1500) loss: 0.6217 time per epoch: 0.1s
# (Epoch 867 / 1500) loss: 0.6495 time per epoch: 0.1s
# (Epoch 868 / 1500) loss: 0.6231 time per epoch: 0.1s
# (Epoch 869 / 1500) loss: 0.6166 time per epoch: 0.1s
# (Epoch 870 / 1500) loss: 0.6640 time per epoch: 0.1s
# (Epoch 871 / 1500) loss: 0.6080 time per epoch: 0.1s
# (Epoch 872 / 1500) loss: 0.6272 time per epoch: 0.1s
# (Epoch 873 / 1500) loss: 0.6351 time per epoch: 0.1s
# (Epoch 874 / 1500) loss: 0.5978 time per epoch: 0.1s
# (Epoch 875 / 1500) loss: 0.6147 time per epoch: 0.1s
# (Epoch 876 / 1500) loss: 0.6059 time per epoch: 0.1s
# (Epoch 877 / 1500) loss: 0.6089 time per epoch: 0.1s
# (Epoch 878 / 1500) loss: 0.6304 time per epoch: 0.1s
# (Epoch 879 / 1500) loss: 0.6159 time per epoch: 0.1s
# (Epoch 880 / 1500) loss: 0.6483 time per epoch: 0.1s
# (Epoch 881 / 1500) loss: 0.6415 time per epoch: 0.1s
# (Epoch 882 / 1500) loss: 0.6283 time per epoch: 0.1s
# (Epoch 883 / 1500) loss: 0.5972 time per epoch: 0.1s
# (Epoch 884 / 1500) loss: 0.5912 time per epoch: 0.1s
# (Epoch 885 / 1500) loss: 0.6101 time per epoch: 0.1s
# (Epoch 886 / 1500) loss: 0.6169 time per epoch: 0.1s
# (Epoch 887 / 1500) loss: 0.6200 time per epoch: 0.1s
# (Epoch 888 / 1500) loss: 0.6218 time per epoch: 0.1s
# (Epoch 889 / 1500) loss: 0.6149 time per epoch: 0.1s
# (Epoch 890 / 1500) loss: 0.5964 time per epoch: 0.1s
# (Epoch 891 / 1500) loss: 0.5951 time per epoch: 0.1s
# (Epoch 892 / 1500) loss: 0.6315 time per epoch: 0.1s
# (Epoch 893 / 1500) loss: 0.5986 time per epoch: 0.1s
# (Epoch 894 / 1500) loss: 0.6178 time per epoch: 0.1s
# (Epoch 895 / 1500) loss: 0.5923 time per epoch: 0.1s
# (Epoch 896 / 1500) loss: 0.5929 time per epoch: 0.1s
# (Epoch 897 / 1500) loss: 0.5953 time per epoch: 0.1s
# (Epoch 898 / 1500) loss: 0.6068 time per epoch: 0.1s
# (Epoch 899 / 1500) loss: 0.5864 time per epoch: 0.1s
# (Epoch 900 / 1500) loss: 0.6299 time per epoch: 0.1s
# (Epoch 901 / 1500) loss: 0.6177 time per epoch: 0.1s
# (Epoch 902 / 1500) loss: 0.6108 time per epoch: 0.1s
# (Epoch 903 / 1500) loss: 0.5701 time per epoch: 0.1s
# (Epoch 904 / 1500) loss: 0.5951 time per epoch: 0.1s
# (Epoch 905 / 1500) loss: 0.6028 time per epoch: 0.1s
# ...
# (Epoch 1204 / 1500) loss: 0.4694 time per epoch: 0.1s
# (Epoch 1205 / 1500) loss: 0.4681 time per epoch: 0.1s
# (Epoch 1206 / 1500) loss: 0.4608 time per epoch: 0.1s
# (Epoch 1207 / 1500) loss: 0.4721 time per epoch: 0.1s
# (Epoch 1208 / 1500) loss: 0.4372 time per epoch: 0.1s
# (Epoch 1209 / 1500) loss: 0.4644 time per epoch: 0.1s
# (Epoch 1210 / 1500) loss: 0.4715 time per epoch: 0.1s
# (Epoch 1211 / 1500) loss: 0.4539 time per epoch: 0.1s
# (Epoch 1212 / 1500) loss: 0.4518 time per epoch: 0.1s
# (Epoch 1213 / 1500) loss: 0.4671 time per epoch: 0.1s
# (Epoch 1214 / 1500) loss: 0.4792 time per epoch: 0.1s
# (Epoch 1215 / 1500) loss: 0.4367 time per epoch: 0.1s
# (Epoch 1216 / 1500) loss: 0.4376 time per epoch: 0.1s
# (Epoch 1217 / 1500) loss: 0.4476 time per epoch: 0.1s
# (Epoch 1218 / 1500) loss: 0.4424 time per epoch: 0.1s
# (Epoch 1219 / 1500) loss: 0.4572 time per epoch: 0.1s
# (Epoch 1220 / 1500) loss: 0.4515 time per epoch: 0.1s
# (Epoch 1221 / 1500) loss: 0.4474 time per epoch: 0.1s
# (Epoch 1222 / 1500) loss: 0.4611 time per epoch: 0.1s
# (Epoch 1223 / 1500) loss: 0.4739 time per epoch: 0.1s
# (Epoch 1224 / 1500) loss: 0.4655 time per epoch: 0.1s
# (Epoch 1225 / 1500) loss: 0.4445 time per epoch: 0.1s
# (Epoch 1226 / 1500) loss: 0.4481 time per epoch: 0.1s
# (Epoch 1227 / 1500) loss: 0.4534 time per epoch: 0.1s
# (Epoch 1228 / 1500) loss: 0.4467 time per epoch: 0.1s
# (Epoch 1229 / 1500) loss: 0.4520 time per epoch: 0.1s
# (Epoch 1230 / 1500) loss: 0.4570 time per epoch: 0.1s
# (Epoch 1231 / 1500) loss: 0.4823 time per epoch: 0.1s
# (Epoch 1232 / 1500) loss: 0.4673 time per epoch: 0.1s
# (Epoch 1233 / 1500) loss: 0.4434 time per epoch: 0.1s
# (Epoch 1234 / 1500) loss: 0.4318 time per epoch: 0.1s
# (Epoch 1235 / 1500) loss: 0.4573 time per epoch: 0.1s
# (Epoch 1236 / 1500) loss: 0.4495 time per epoch: 0.1s
# (Epoch 1237 / 1500) loss: 0.4553 time per epoch: 0.1s
# (Epoch 1238 / 1500) loss: 0.4535 time per epoch: 0.1s
# (Epoch 1239 / 1500) loss: 0.4727 time per epoch: 0.1s
# (Epoch 1240 / 1500) loss: 0.4549 time per epoch: 0.1s
# (Epoch 1241 / 1500) loss: 0.4474 time per epoch: 0.1s
# (Epoch 1242 / 1500) loss: 0.4432 time per epoch: 0.1s
# (Epoch 1243 / 1500) loss: 0.4360 time per epoch: 0.1s
# (Epoch 1244 / 1500) loss: 0.4404 time per epoch: 0.1s
# (Epoch 1245 / 1500) loss: 0.4712 time per epoch: 0.1s
# (Epoch 1246 / 1500) loss: 0.4544 time per epoch: 0.1s
# (Epoch 1247 / 1500) loss: 0.4412 time per epoch: 0.1s
# (Epoch 1248 / 1500) loss: 0.4290 time per epoch: 0.1s
# (Epoch 1249 / 1500) loss: 0.4631 time per epoch: 0.1s
# (Epoch 1250 / 1500) loss: 0.4699 time per epoch: 0.1s
# (Epoch 1251 / 1500) loss: 0.4267 time per epoch: 0.1s
# (Epoch 1252 / 1500) loss: 0.4785 time per epoch: 0.1s
# (Epoch 1253 / 1500) loss: 0.4656 time per epoch: 0.1s
# (Epoch 1254 / 1500) loss: 0.4670 time per epoch: 0.1s
# (Epoch 1255 / 1500) loss: 0.4542 time per epoch: 0.1s
# (Epoch 1256 / 1500) loss: 0.4191 time per epoch: 0.1s
# (Epoch 1257 / 1500) loss: 0.4338 time per epoch: 0.1s
# (Epoch 1258 / 1500) loss: 0.4547 time per epoch: 0.1s
# (Epoch 1259 / 1500) loss: 0.4300 time per epoch: 0.1s
# (Epoch 1260 / 1500) loss: 0.4299 time per epoch: 0.1s
# (Epoch 1261 / 1500) loss: 0.4441 time per epoch: 0.1s
# (Epoch 1262 / 1500) loss: 0.4138 time per epoch: 0.1s
# (Epoch 1263 / 1500) loss: 0.4058 time per epoch: 0.1s
# (Epoch 1264 / 1500) loss: 0.4536 time per epoch: 0.1s
# (Epoch 1265 / 1500) loss: 0.4286 time per epoch: 0.1s
# (Epoch 1266 / 1500) loss: 0.4146 time per epoch: 0.1s
# (Epoch 1267 / 1500) loss: 0.4425 time per epoch: 0.1s
# (Epoch 1268 / 1500) loss: 0.4293 time per epoch: 0.1s
# (Epoch 1269 / 1500) loss: 0.4817 time per epoch: 0.1s
# (Epoch 1270 / 1500) loss: 0.4369 time per epoch: 0.1s
# (Epoch 1271 / 1500) loss: 0.4274 time per epoch: 0.1s
# (Epoch 1272 / 1500) loss: 0.4169 time per epoch: 0.1s
# (Epoch 1273 / 1500) loss: 0.4331 time per epoch: 0.1s
# (Epoch 1274 / 1500) loss: 0.4470 time per epoch: 0.1s
# (Epoch 1275 / 1500) loss: 0.4102 time per epoch: 0.1s
# (Epoch 1276 / 1500) loss: 0.4569 time per epoch: 0.1s
# (Epoch 1277 / 1500) loss: 0.4296 time per epoch: 0.1s
# (Epoch 1278 / 1500) loss: 0.4510 time per epoch: 0.1s
# (Epoch 1279 / 1500) loss: 0.4452 time per epoch: 0.1s
# (Epoch 1280 / 1500) loss: 0.4275 time per epoch: 0.1s
# (Epoch 1281 / 1500) loss: 0.4344 time per epoch: 0.1s
# (Epoch 1282 / 1500) loss: 0.4242 time per epoch: 0.1s
# (Epoch 1283 / 1500) loss: 0.4315 time per epoch: 0.1s
# (Epoch 1284 / 1500) loss: 0.4445 time per epoch: 0.1s
# (Epoch 1285 / 1500) loss: 0.4256 time per epoch: 0.1s
# (Epoch 1286 / 1500) loss: 0.4395 time per epoch: 0.1s
# (Epoch 1287 / 1500) loss: 0.4250 time per epoch: 0.1s
# (Epoch 1288 / 1500) loss: 0.4474 time per epoch: 0.1s
# (Epoch 1289 / 1500) loss: 0.4297 time per epoch: 0.1s
# (Epoch 1290 / 1500) loss: 0.4439 time per epoch: 0.1s
# (Epoch 1291 / 1500) loss: 0.4223 time per epoch: 0.1s
# (Epoch 1292 / 1500) loss: 0.4444 time per epoch: 0.1s
# (Epoch 1293 / 1500) loss: 0.4293 time per epoch: 0.1s
# (Epoch 1294 / 1500) loss: 0.4318 time per epoch: 0.1s
# (Epoch 1295 / 1500) loss: 0.4557 time per epoch: 0.1s
# (Epoch 1296 / 1500) loss: 0.4236 time per epoch: 0.1s
# (Epoch 1297 / 1500) loss: 0.4266 time per epoch: 0.1s
# (Epoch 1298 / 1500) loss: 0.4406 time per epoch: 0.1s
# (Epoch 1299 / 1500) loss: 0.4391 time per epoch: 0.1s
# (Epoch 1300 / 1500) loss: 0.4302 time per epoch: 0.1s
# (Epoch 1301 / 1500) loss: 0.4654 time per epoch: 0.1s
# (Epoch 1302 / 1500) loss: 0.4142 time per epoch: 0.1s
# (Epoch 1303 / 1500) loss: 0.4297 time per epoch: 0.1s
# (Epoch 1304 / 1500) loss: 0.4307 time per epoch: 0.1s
# (Epoch 1305 / 1500) loss: 0.4170 time per epoch: 0.1s
# (Epoch 1306 / 1500) loss: 0.4402 time per epoch: 0.1s
# (Epoch 1307 / 1500) loss: 0.4210 time per epoch: 0.1s
# (Epoch 1308 / 1500) loss: 0.4215 time per epoch: 0.1s
# (Epoch 1309 / 1500) loss: 0.4438 time per epoch: 0.1s
# (Epoch 1310 / 1500) loss: 0.4307 time per epoch: 0.1s
# (Epoch 1311 / 1500) loss: 0.4258 time per epoch: 0.1s
# (Epoch 1312 / 1500) loss: 0.4281 time per epoch: 0.1s
# (Epoch 1313 / 1500) loss: 0.4246 time per epoch: 0.1s
# (Epoch 1314 / 1500) loss: 0.4239 time per epoch: 0.1s
# (Epoch 1315 / 1500) loss: 0.3997 time per epoch: 0.1s
# (Epoch 1316 / 1500) loss: 0.4367 time per epoch: 0.1s
# (Epoch 1317 / 1500) loss: 0.4441 time per epoch: 0.1s
# (Epoch 1318 / 1500) loss: 0.4116 time per epoch: 0.1s
# (Epoch 1319 / 1500) loss: 0.4180 time per epoch: 0.1s
# (Epoch 1320 / 1500) loss: 0.4296 time per epoch: 0.1s
# (Epoch 1321 / 1500) loss: 0.3852 time per epoch: 0.1s
# (Epoch 1322 / 1500) loss: 0.4143 time per epoch: 0.1s
# (Epoch 1323 / 1500) loss: 0.4445 time per epoch: 0.1s
# (Epoch 1324 / 1500) loss: 0.4088 time per epoch: 0.1s
# (Epoch 1325 / 1500) loss: 0.4473 time per epoch: 0.1s
# (Epoch 1326 / 1500) loss: 0.4196 time per epoch: 0.1s
# (Epoch 1327 / 1500) loss: 0.4255 time per epoch: 0.1s
# (Epoch 1328 / 1500) loss: 0.4181 time per epoch: 0.1s
# (Epoch 1329 / 1500) loss: 0.4213 time per epoch: 0.1s
# (Epoch 1330 / 1500) loss: 0.3881 time per epoch: 0.1s
# (Epoch 1331 / 1500) loss: 0.4118 time per epoch: 0.1s
# (Epoch 1332 / 1500) loss: 0.4171 time per epoch: 0.1s
# (Epoch 1333 / 1500) loss: 0.4466 time per epoch: 0.1s
# (Epoch 1334 / 1500) loss: 0.4049 time per epoch: 0.1s
# (Epoch 1335 / 1500) loss: 0.4195 time per epoch: 0.1s
# (Epoch 1336 / 1500) loss: 0.4152 time per epoch: 0.1s
# (Epoch 1337 / 1500) loss: 0.4306 time per epoch: 0.1s
# (Epoch 1338 / 1500) loss: 0.4199 time per epoch: 0.1s
# (Epoch 1339 / 1500) loss: 0.4066 time per epoch: 0.1s
# (Epoch 1340 / 1500) loss: 0.4277 time per epoch: 0.1s
# (Epoch 1341 / 1500) loss: 0.3834 time per epoch: 0.1s
# (Epoch 1342 / 1500) loss: 0.3846 time per epoch: 0.1s
# (Epoch 1343 / 1500) loss: 0.4164 time per epoch: 0.1s
# (Epoch 1344 / 1500) loss: 0.3924 time per epoch: 0.1s
# (Epoch 1345 / 1500) loss: 0.4245 time per epoch: 0.1s
# (Epoch 1346 / 1500) loss: 0.4303 time per epoch: 0.1s
# (Epoch 1347 / 1500) loss: 0.3958 time per epoch: 0.1s
# (Epoch 1348 / 1500) loss: 0.4146 time per epoch: 0.1s
# (Epoch 1349 / 1500) loss: 0.4048 time per epoch: 0.1s
# (Epoch 1350 / 1500) loss: 0.4215 time per epoch: 0.1s
# (Epoch 1351 / 1500) loss: 0.4149 time per epoch: 0.1s
# (Epoch 1352 / 1500) loss: 0.4081 time per epoch: 0.1s
# (Epoch 1353 / 1500) loss: 0.4193 time per epoch: 0.1s
# (Epoch 1354 / 1500) loss: 0.3962 time per epoch: 0.1s
# (Epoch 1355 / 1500) loss: 0.4229 time per epoch: 0.1s
# (Epoch 1356 / 1500) loss: 0.4053 time per epoch: 0.1s
# (Epoch 1357 / 1500) loss: 0.4234 time per epoch: 0.1s
# (Epoch 1358 / 1500) loss: 0.4010 time per epoch: 0.1s
# (Epoch 1359 / 1500) loss: 0.4389 time per epoch: 0.1s
# (Epoch 1360 / 1500) loss: 0.4109 time per epoch: 0.1s
# (Epoch 1361 / 1500) loss: 0.3864 time per epoch: 0.1s
# (Epoch 1362 / 1500) loss: 0.3977 time per epoch: 0.1s
# (Epoch 1363 / 1500) loss: 0.4272 time per epoch: 0.1s
# (Epoch 1364 / 1500) loss: 0.4003 time per epoch: 0.1s
# (Epoch 1365 / 1500) loss: 0.4175 time per epoch: 0.1s
# (Epoch 1366 / 1500) loss: 0.4085 time per epoch: 0.1s
# (Epoch 1367 / 1500) loss: 0.3979 time per epoch: 0.1s
# (Epoch 1368 / 1500) loss: 0.4150 time per epoch: 0.1s
# (Epoch 1369 / 1500) loss: 0.3868 time per epoch: 0.1s
# (Epoch 1370 / 1500) loss: 0.4353 time per epoch: 0.1s
# (Epoch 1371 / 1500) loss: 0.4109 time per epoch: 0.1s
# (Epoch 1372 / 1500) loss: 0.4081 time per epoch: 0.1s
# (Epoch 1373 / 1500) loss: 0.4144 time per epoch: 0.1s
# (Epoch 1374 / 1500) loss: 0.3930 time per epoch: 0.1s
# (Epoch 1375 / 1500) loss: 0.4323 time per epoch: 0.1s
# (Epoch 1376 / 1500) loss: 0.4114 time per epoch: 0.1s
# (Epoch 1377 / 1500) loss: 0.4183 time per epoch: 0.1s
# (Epoch 1378 / 1500) loss: 0.4243 time per epoch: 0.1s
# (Epoch 1379 / 1500) loss: 0.4220 time per epoch: 0.1s
# (Epoch 1380 / 1500) loss: 0.4053 time per epoch: 0.1s
# (Epoch 1381 / 1500) loss: 0.4105 time per epoch: 0.1s
# (Epoch 1382 / 1500) loss: 0.3850 time per epoch: 0.1s
# (Epoch 1383 / 1500) loss: 0.4343 time per epoch: 0.1s
# (Epoch 1384 / 1500) loss: 0.4008 time per epoch: 0.1s
# (Epoch 1385 / 1500) loss: 0.4105 time per epoch: 0.1s
# (Epoch 1386 / 1500) loss: 0.3830 time per epoch: 0.1s
# (Epoch 1387 / 1500) loss: 0.4111 time per epoch: 0.1s
# (Epoch 1388 / 1500) loss: 0.3746 time per epoch: 0.1s
# (Epoch 1389 / 1500) loss: 0.3894 time per epoch: 0.1s
# (Epoch 1390 / 1500) loss: 0.4042 time per epoch: 0.1s
# (Epoch 1391 / 1500) loss: 0.4190 time per epoch: 0.1s
# (Epoch 1392 / 1500) loss: 0.3917 time per epoch: 0.1s
# (Epoch 1393 / 1500) loss: 0.4383 time per epoch: 0.1s
# (Epoch 1394 / 1500) loss: 0.3810 time per epoch: 0.1s
# (Epoch 1395 / 1500) loss: 0.4085 time per epoch: 0.1s
# (Epoch 1396 / 1500) loss: 0.4011 time per epoch: 0.1s
# (Epoch 1397 / 1500) loss: 0.4074 time per epoch: 0.1s
# (Epoch 1398 / 1500) loss: 0.4178 time per epoch: 0.1s
# (Epoch 1399 / 1500) loss: 0.4106 time per epoch: 0.1s
# (Epoch 1400 / 1500) loss: 0.4014 time per epoch: 0.1s
# (Epoch 1401 / 1500) loss: 0.4111 time per epoch: 0.1s
# (Epoch 1402 / 1500) loss: 0.4120 time per epoch: 0.1s
# (Epoch 1403 / 1500) loss: 0.4048 time per epoch: 0.1s
# (Epoch 1404 / 1500) loss: 0.3764 time per epoch: 0.1s
# (Epoch 1405 / 1500) loss: 0.4297 time per epoch: 0.1s
# (Epoch 1406 / 1500) loss: 0.3909 time per epoch: 0.1s
# (Epoch 1407 / 1500) loss: 0.3970 time per epoch: 0.1s
# (Epoch 1408 / 1500) loss: 0.3927 time per epoch: 0.1s
# (Epoch 1409 / 1500) loss: 0.3947 time per epoch: 0.1s
# (Epoch 1410 / 1500) loss: 0.3808 time per epoch: 0.1s
# (Epoch 1411 / 1500) loss: 0.4031 time per epoch: 0.1s
# (Epoch 1412 / 1500) loss: 0.4074 time per epoch: 0.1s
# (Epoch 1413 / 1500) loss: 0.3852 time per epoch: 0.1s
# (Epoch 1414 / 1500) loss: 0.4093 time per epoch: 0.1s
# (Epoch 1415 / 1500) loss: 0.3820 time per epoch: 0.1s
# (Epoch 1416 / 1500) loss: 0.3906 time per epoch: 0.1s
# (Epoch 1417 / 1500) loss: 0.3969 time per epoch: 0.1s
# (Epoch 1418 / 1500) loss: 0.3809 time per epoch: 0.1s
# (Epoch 1419 / 1500) loss: 0.3785 time per epoch: 0.1s
# (Epoch 1420 / 1500) loss: 0.4014 time per epoch: 0.1s
# (Epoch 1421 / 1500) loss: 0.3757 time per epoch: 0.1s
# (Epoch 1422 / 1500) loss: 0.3700 time per epoch: 0.1s
# (Epoch 1423 / 1500) loss: 0.4198 time per epoch: 0.1s
# (Epoch 1424 / 1500) loss: 0.3840 time per epoch: 0.1s
# (Epoch 1425 / 1500) loss: 0.3772 time per epoch: 0.1s
# (Epoch 1426 / 1500) loss: 0.3794 time per epoch: 0.1s
# (Epoch 1427 / 1500) loss: 0.3655 time per epoch: 0.1s
# (Epoch 1428 / 1500) loss: 0.4020 time per epoch: 0.1s
# (Epoch 1429 / 1500) loss: 0.3910 time per epoch: 0.1s
# (Epoch 1430 / 1500) loss: 0.3736 time per epoch: 0.1s
# (Epoch 1431 / 1500) loss: 0.4280 time per epoch: 0.1s
# (Epoch 1432 / 1500) loss: 0.4000 time per epoch: 0.1s
# (Epoch 1433 / 1500) loss: 0.3925 time per epoch: 0.1s
# (Epoch 1434 / 1500) loss: 0.3856 time per epoch: 0.1s
# (Epoch 1435 / 1500) loss: 0.3719 time per epoch: 0.1s
# (Epoch 1436 / 1500) loss: 0.3691 time per epoch: 0.1s
# (Epoch 1437 / 1500) loss: 0.3748 time per epoch: 0.1s
# (Epoch 1438 / 1500) loss: 0.3953 time per epoch: 0.1s
# (Epoch 1439 / 1500) loss: 0.3962 time per epoch: 0.1s
# (Epoch 1440 / 1500) loss: 0.3939 time per epoch: 0.1s
# (Epoch 1441 / 1500) loss: 0.3912 time per epoch: 0.1s
# (Epoch 1442 / 1500) loss: 0.3848 time per epoch: 0.1s
# (Epoch 1443 / 1500) loss: 0.3984 time per epoch: 0.1s
# (Epoch 1444 / 1500) loss: 0.3901 time per epoch: 0.1s
# (Epoch 1445 / 1500) loss: 0.3890 time per epoch: 0.1s
# (Epoch 1446 / 1500) loss: 0.3905 time per epoch: 0.1s
# (Epoch 1447 / 1500) loss: 0.3924 time per epoch: 0.1s
# (Epoch 1448 / 1500) loss: 0.3448 time per epoch: 0.1s
# (Epoch 1449 / 1500) loss: 0.3802 time per epoch: 0.1s
# (Epoch 1450 / 1500) loss: 0.4034 time per epoch: 0.1s
# (Epoch 1451 / 1500) loss: 0.3631 time per epoch: 0.1s
# (Epoch 1452 / 1500) loss: 0.3666 time per epoch: 0.1s
# (Epoch 1453 / 1500) loss: 0.3842 time per epoch: 0.1s
# (Epoch 1454 / 1500) loss: 0.4005 time per epoch: 0.1s
# (Epoch 1455 / 1500) loss: 0.3648 time per epoch: 0.1s
# (Epoch 1456 / 1500) loss: 0.4135 time per epoch: 0.1s
# (Epoch 1457 / 1500) loss: 0.4004 time per epoch: 0.1s
# (Epoch 1458 / 1500) loss: 0.3743 time per epoch: 0.1s
# (Epoch 1459 / 1500) loss: 0.3690 time per epoch: 0.1s
# (Epoch 1460 / 1500) loss: 0.3959 time per epoch: 0.1s
# (Epoch 1461 / 1500) loss: 0.3633 time per epoch: 0.1s
# (Epoch 1462 / 1500) loss: 0.3654 time per epoch: 0.1s
# (Epoch 1463 / 1500) loss: 0.3691 time per epoch: 0.1s
# (Epoch 1464 / 1500) loss: 0.3787 time per epoch: 0.1s
# (Epoch 1465 / 1500) loss: 0.3871 time per epoch: 0.1s
# (Epoch 1466 / 1500) loss: 0.3655 time per epoch: 0.1s
# (Epoch 1467 / 1500) loss: 0.3811 time per epoch: 0.1s
# (Epoch 1468 / 1500) loss: 0.3803 time per epoch: 0.1s
# (Epoch 1469 / 1500) loss: 0.3663 time per epoch: 0.1s
# (Epoch 1470 / 1500) loss: 0.3724 time per epoch: 0.1s
# (Epoch 1471 / 1500) loss: 0.3797 time per epoch: 0.1s
# (Epoch 1472 / 1500) loss: 0.3548 time per epoch: 0.1s
# (Epoch 1473 / 1500) loss: 0.3480 time per epoch: 0.1s
# (Epoch 1474 / 1500) loss: 0.3800 time per epoch: 0.1s
# (Epoch 1475 / 1500) loss: 0.3557 time per epoch: 0.1s
# (Epoch 1476 / 1500) loss: 0.3693 time per epoch: 0.1s
# (Epoch 1477 / 1500) loss: 0.3919 time per epoch: 0.1s
# (Epoch 1478 / 1500) loss: 0.3701 time per epoch: 0.1s
# (Epoch 1479 / 1500) loss: 0.3681 time per epoch: 0.1s
# (Epoch 1480 / 1500) loss: 0.3694 time per epoch: 0.1s
# (Epoch 1481 / 1500) loss: 0.3715 time per epoch: 0.1s
# (Epoch 1482 / 1500) loss: 0.3757 time per epoch: 0.1s
# (Epoch 1483 / 1500) loss: 0.3853 time per epoch: 0.1s
# (Epoch 1484 / 1500) loss: 0.3696 time per epoch: 0.1s
# (Epoch 1485 / 1500) loss: 0.3505 time per epoch: 0.1s
# (Epoch 1486 / 1500) loss: 0.3802 time per epoch: 0.1s
# (Epoch 1487 / 1500) loss: 0.3624 time per epoch: 0.1s
# (Epoch 1488 / 1500) loss: 0.3855 time per epoch: 0.1s
# (Epoch 1489 / 1500) loss: 0.3509 time per epoch: 0.1s
# (Epoch 1490 / 1500) loss: 0.3904 time per epoch: 0.1s
# (Epoch 1491 / 1500) loss: 0.3763 time per epoch: 0.1s
# (Epoch 1492 / 1500) loss: 0.3610 time per epoch: 0.1s
# (Epoch 1493 / 1500) loss: 0.3702 time per epoch: 0.1s
# (Epoch 1494 / 1500) loss: 0.3816 time per epoch: 0.1s
# (Epoch 1495 / 1500) loss: 0.3641 time per epoch: 0.1s
# (Epoch 1496 / 1500) loss: 0.3633 time per epoch: 0.1s
# (Epoch 1497 / 1500) loss: 0.3499 time per epoch: 0.1s
# (Epoch 1498 / 1500) loss: 0.3465 time per epoch: 0.1s
# (Epoch 1499 / 1500) loss: 0.4027 time per epoch: 0.1s

# %%
probB #(B, N, 4-class)
